# %% [markdown]
# ### 행정구역 정보 분석 및 시각화
# 1. pandas의 read_csv() 함수로 csv file을 읽어서 DataFrame 객체로 생성하고 데이터 확인하기
# 2. Data Selection : loc[] / iloc[] 를 사용해서 특정 Row와 Column 선택하기
# 3. 컬럼명 변경하기
# 4. DataFrame 객체를 Excel file로 저장하기
# 5. Data Grouping : groupby() 함수를 사용해서 그룹핑하기
# 6. 상관관계 분석 : corr() 함수를 사용해서 인구수와 면적간의 상관관계
# 7. 시각화 : seaborn의 barplot() 함수를 사용해서 Plot 그리기

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 3.0.5

# %% [markdown]
# ##### pandas의 read_csv() 함수로 csv file을 읽어서 DataFrame 객체로 생성하고 데이터 확인하기

# %%
data = pd.read_csv('data/data_draw_korea.csv')
print(data.shape)
print(type(data))
# Out:
# (229, 8)
# <class 'pandas.DataFrame'>

# %%
# head() 함수
data.head()
# Out:
#    Unnamed: 0     인구수 shortName   x  y       면적 광역시도 행정구역
# 0           0  202520        강릉  11  4  1040.07  강원도  강릉시
# 1           1   25589    고성(강원)   9  0   664.19  강원도  고성군
# 2           2   86747        동해  11  5   180.01  강원도  동해시
# 3           3   63986        삼척  11  8  1185.80  강원도  삼척시
# 4           4   76733        속초   9  1   105.25  강원도  속초시

# %%
# tail() 함수
data.tail()
# Out:
#      Unnamed: 0     인구수 shortName  x   y      면적  광역시도 행정구역
# 224         224  127462        제천  8  10  882.47  충청북도  제천시
# 225         225   34480        증평  6  11   81.84  충청북도  증평군
# 226         226   62809        진천  5  11  406.08  충청북도  진천군
# 227         227  790216        청주  6  12  932.51  충청북도  청주시
# 228         228  198077        충주  6  10  983.70  충청북도  충주시

# %%
# sample() 함수_임의의 랜덤_default -> 1
data.sample(3)
# Out:
#     Unnamed: 0     인구수 shortName   x   y      면적   광역시도 행정구역
# 97          97  178203      대구달성   9  15  427.03  대구광역시  달성군
# 66          66   42515        합천   7  14  983.42   경상남도  합천군
# 2            2   86747        동해  11   5  180.01    강원도  동해시

# %%
# 컬렴명 확인하기
print(f'컬럼명 = {data.columns}')
# 인덱스 확인하기
print(f'인덱스 = {data.index}')
# Out:
# 컬럼명 = Index(['Unnamed: 0', '인구수', 'shortName', 'x', 'y', '면적', '광역시도', '행정구역'], dtype='str')
# 인덱스 = RangeIndex(start=0, stop=229, step=1)

# %%
# values 속성으로 값 확인하기
print(type(data.values))
data.values
# Out:
# <class 'numpy.ndarray'>
# array([[0, 202520, '강릉', ..., 1040.07, '강원도', '강릉시'],
#        [1, 25589, '고성(강원)', ..., 664.19, '강원도', '고성군'],
#        [2, 86747, '동해', ..., 180.01, '강원도', '동해시'],
#        ...,
#        [226, 62809, '진천', ..., 406.08, '충청북도', '진천군'],
#        [227, 790216, '청주', ..., 932.51, '충청북도', '청주시'],
#        [228, 198077, '충주', ..., 983.7, '충청북도', '충주시']],
#       shape=(229, 8), dtype=object)

# %%
# info() 함수
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  229 non-null    int64
#  1   인구수         229 non-null    int64
#  2   shortName   229 non-null    str
#  3   x           229 non-null    int64
#  4   y           229 non-null    int64
#  5   면적          229 non-null    float64
#  6   광역시도        229 non-null    str
#  7   행정구역        229 non-null    str
# dtypes: float64(1), int64(4), str(3)
# memory usage: 14.4 KB

# %%
# 모든 컬럼의 타입 확인
print(type(data.dtypes))
data.dtypes
# Out:
# <class 'pandas.Series'>
# Unnamed: 0      int64
# 인구수             int64
# shortName         str
# x               int64
# y               int64
# 면적            float64
# 광역시도              str
# 행정구역              str
# dtype: object

# %%
# 면적 컬럼 값 타입을 확인
print(type(data['면적']))

#면적 컬럼의 타입
print((data['면적'].dtype))

#면적 컬럼의 값
data['면적']
# Out:
# <class 'pandas.Series'>
# float64
# 0      1040.07
# 1       664.19
# 2       180.01
# 3      1185.80
# 4       105.25
#         ...
# 224     882.47
# 225      81.84
# 226     406.08
# 227     932.51
# 228     983.70
# Name: 면적, Length: 229, dtype: float64

# %%
# 특정컬럼(인구수)의 타입 확인
print(type(data['인구수']))
print(data['인구수'].dtype)
# Out:
# <class 'pandas.Series'>
# int64

# %%
# describe() 함수, 숫자 타입인 컬럼의 통계함수 출력
data.describe()
# Out:
#        Unnamed: 0           인구수           x           y           면적
# count  229.000000  2.290000e+02  229.000000  229.000000   229.000000
# mean   114.000000  2.110898e+05    6.117904   11.262009   435.419795
# std     66.250786  2.074378e+05    3.320469    6.040898   381.612549
# min      0.000000  8.392000e+03    0.000000    0.000000     2.800000
# 25%     57.000000  4.955900e+04    3.000000    6.000000    54.000000
# 50%    114.000000  1.401590e+05    6.000000   11.000000   436.400000
# 75%    171.000000  3.216180e+05    9.000000   16.000000   692.800000
# max    228.000000  1.125461e+06   13.000000   25.000000  1817.940000

# %%
import numpy as np


data.describe(include = np.number)
# Out:
#        Unnamed: 0           인구수           x           y           면적
# count  229.000000  2.290000e+02  229.000000  229.000000   229.000000
# mean   114.000000  2.110898e+05    6.117904   11.262009   435.419795
# std     66.250786  2.074378e+05    3.320469    6.040898   381.612549
# min      0.000000  8.392000e+03    0.000000    0.000000     2.800000
# 25%     57.000000  4.955900e+04    3.000000    6.000000    54.000000
# 50%    114.000000  1.401590e+05    6.000000   11.000000   436.400000
# 75%    171.000000  3.216180e+05    9.000000   16.000000   692.800000
# max    228.000000  1.125461e+06   13.000000   25.000000  1817.940000

# %%
# describe() 함수, 문자열(object) 타입인 컬럼의 통계함수 출력
data.describe(include=[object])
# Out:
# C:\Users\User.DESKTOP-G5S2APU\AppData\Local\Temp\ipykernel_24460\3131804066.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   data.describe(include=[object])
#        shortName 광역시도 행정구역
# count        229  229  229
# unique       229   17  206
# top           강릉  경기도   동구
# freq           1   31    6

# %%
# data['행정구역'] == '동구'
data['행정구역'] == '동구'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 224    False
# 225    False
# 226    False
# 227    False
# 228    False
# Name: 행정구역, Length: 229, dtype: bool

# %%
# 해당 조건식과 매칭되는 Row data 출력
# data.Loc[row 선택, col선택] 또는 data.Loc[row 선택] (모든 컬럼이 선택됨), data.loc[:, col 선택] (모든 행이 선택됨)
data.loc[data['행정구역'] == '동구']
# Out:
#      Unnamed: 0     인구수 shortName   x   y      면적   광역시도 행정구역
# 92           92   97571      광주동구   3  20   48.86  광주광역시   동구
# 98           98  330830      대구동구  11  13  182.35  대구광역시   동구
# 104         104  236524      대전동구   5  13  136.80  대전광역시   동구
# 112         112   85952      부산동구  10  17    9.77  부산광역시   동구
# 151         151  164738      울산동구  12  14   35.77  울산광역시   동구
# 159         159   68950      인천동구   1   5    7.05  인천광역시   동구

# %%
# '광역시도' == '경기도' _ 시리즈 객체의 예시
data.loc[data['광역시도'] == '경기도','인구수'] 
# '광역시도' == '경기도' _ 컬럼 2개 선택시 데이터프레임 객체가 됨
data.loc[data['광역시도'] == '경기도',['인구수', '행정구역', '면적']].reset_index(drop = True)
# Out:
#         인구수  행정구역       면적
# 0     53497   가평군  843.040
# 1    955384   고양시  267.330
# 2     63227   과천시   35.813
# 3    327111   광명시   38.500
# 4    290210   광주시  431.840
# 5    175676   구리시   33.300
# 6    273302   군포시   36.350
# 7    326523   김포시  276.640
# 8    610300  남양주시  458.440
# 9     90398  동두천시   95.680
# 10   805473   부천시   53.440
# 11   911628   성남시  141.820
# 12  1125461   수원시  121.090
# 13   381412   시흥시  134.400
# 14   668089   안산시  144.780
# 15   173061   안성시  554.200
# 16   566558   안양시   58.520
# 17   191266   양주시  310.310
# 18    95614   양평군  877.080
# 19   100669   여주시  608.640
# 20    41076   연천군  695.230
# 21   200793   오산시   42.740
# 22   915005   용인시  591.500
# 23   149080   의왕시   54.000
# 24   408220  의정부시   81.590
# 25   190537   이천시  461.020
# 26   385528   파주시  672.560
# 27   423763   평택시  452.310
# 28   140159   포천시  826.380
# 29   150061   하남시   93.100
# 30   555129   화성시  688.100

# %%
# describe() 함수, 모든 컬럼의 통계함수 출력
data.describe(include='all')
# Out:
#         Unnamed: 0           인구수 shortName           x           y  \
# count   229.000000  2.290000e+02       229  229.000000  229.000000
# unique         NaN           NaN       229         NaN         NaN
# top            NaN           NaN        강릉         NaN         NaN
# freq           NaN           NaN         1         NaN         NaN
# mean    114.000000  2.110898e+05       NaN    6.117904   11.262009
# std      66.250786  2.074378e+05       NaN    3.320469    6.040898
# min       0.000000  8.392000e+03       NaN    0.000000    0.000000
# 25%      57.000000  4.955900e+04       NaN    3.000000    6.000000
# 50%     114.000000  1.401590e+05       NaN    6.000000   11.000000
# 75%     171.000000  3.216180e+05       NaN    9.000000   16.000000
# max     228.000000  1.125461e+06       NaN   13.000000   25.000000
#
#                  면적 광역시도 행정구역
# count    229.000000  229  229
# unique          NaN   17  206
# top             NaN  경기도   동구
# freq            NaN   31    6
# mean     435.419795  NaN  NaN
# std      381.612549  NaN  NaN
# min        2.800000  NaN  NaN
# 25%       54.000000  NaN  NaN
# 50%      436.400000  NaN  NaN
# 75%      692.800000  NaN  NaN
# max     1817.940000  NaN  NaN

# %% [markdown]
# ### Data Selection
# * loc[] 또는 iloc[]
# * loc[Row 선택, Column 선택]

# %%
# 인구수 1개의 컬럼 선택
print(type(data['인구수']))
data['인구수']
# Out:
# <class 'pandas.core.series.Series'>
# 0      202520
# 1       25589
# 2       86747
# 3       63986
# 4       76733
#         ...
# 224    127462
# 225     34480
# 226     62809
# 227    790216
# 228    198077
# Name: 인구수, Length: 229, dtype: int64

# %%
data.loc[:,'인구수']

# %%
# ['행정구역','인구수','면적'] 컬럼의 데이터 출력
data[['행정구역','인구수','면적']]

# %%
# if loc 사용(+구간 적용)
data.loc[0:10,['행정구역','인구수','면적']]

# %%
# 인구수 컬럼의 집계함수
print(f"인구수 최대값 {data['인구수'].max():,}")
print(f"인구수 최소값 {data['인구수'].min():,}")
print(f"인구수 평균 {round(data['인구수'].mean()):,}")
print(f"인구수 표준편차 {round(data['인구수'].std()):,}")
print(f"인구수 중간값 {data['인구수'].median():,}")
data['인구수'].quantile([0.25, 0.75])
# Out:
# 인구수 최대값 1,125,461
# 인구수 최소값 8,392
# 인구수 평균 211,090
# 인구수 표준편차 207,438
# 인구수 중간값 140,159.0
# 0.25     49559.0
# 0.75    321618.0
# Name: 인구수, dtype: float64

# %%
# 인구수가 가장 많은 행정구역?
# 인구수의 최대값을 max_prop 변수에 저장

max_prop = data['인구수'].max()
print(max_prop)
data.loc[data['인구수']==max_prop]
# Out:
# 1125461
#     Unnamed: 0      인구수 shortName  x  y      면적 광역시도 행정구역
# 30          30  1125461        수원  6  9  121.09  경기도  수원시

# %%
# 면적이 넓은 행정구역?

data.loc[data['면적']== data['면적'].max()]
# Out:
#     Unnamed: 0    인구수 shortName   x  y       면적 광역시도 행정구역
# 15          15  62957        홍천  10  4  1817.94  강원도  홍천군

# %%
# 인구수가 가장 적은 행정구역?
data.loc[data['인구수']== data['인구수'].min()]
# Out:
#     Unnamed: 0   인구수 shortName   x  y     면적  광역시도 행정구역
# 83          83  8392        울릉  13  6  72.82  경상북도  울릉군

# %% [markdown]
# * 인구수가 전국 인구수의 평균 보다 크거나 같은 행정구역 정보를 출력하세요 ( index는 reset )
# * 광역시도, 행정구역, 인구수

# %%
data.loc[data['인구수']>=data['인구수'].mean(), ['광역시도', '행정구역','인구수']]\
    .sort_values(['인구수',ascending = False).reset_index(drop = True)
# Out:
#        광역시도 행정구역     인구수
# 0       강원도  원주시  313851
# 1       강원도  춘천시  264144
# 2       경기도  고양시  955384
# 3       경기도  광명시  327111
# 4       경기도  광주시  290210
# ..      ...  ...     ...
# 83     전라북도  전주시  630708
# 84  제주특별자치도  제주시  430504
# 85     충청남도  아산시  281938
# 86     충청남도  천안시  584912
# 87     충청북도  청주시  790216
#
# [88 rows x 3 columns]

# %%
# unique한 광역시도명
data['광역시도'].unique()
# Out:
# <StringArray>
# [    '강원도',     '경기도',    '경상남도',    '경상북도',   '광주광역시',   '대구광역시',   '대전광역시',
#    '부산광역시',   '서울특별시', '세종특별자치시',   '울산광역시',   '인천광역시',    '전라남도',    '전라북도',
#  '제주특별자치도',    '충청남도',    '충청북도']
# Length: 17, dtype: str

# %%
# 광역시도별 Row Counting
data['광역시도'].value_counts()
# Out:
# 광역시도
# 경기도        31
# 서울특별시      25
# 경상북도       23
# 전라남도       22
# 강원도        18
# 경상남도       18
# 부산광역시      16
# 충청남도       15
# 전라북도       14
# 충청북도       11
# 인천광역시      10
# 대구광역시       8
# 광주광역시       5
# 대전광역시       5
# 울산광역시       5
# 제주특별자치도     2
# 세종특별자치시     1
# Name: count, dtype: int64

# %%
# data['행정구역'] == '경기도' 의 ['행정구역','인구수','면적']  컬럼의 데이터 출력하기
gy_df = data.loc[data['광역시도'] == '경기도',['행정구역','인구수','면적']]\
.sort_values(by='인구수',ascending=False).reset_index(drop=True)
gy_df
# Out:
#     행정구역      인구수       면적
# 0    수원시  1125461  121.090
# 1    고양시   955384  267.330
# 2    용인시   915005  591.500
# 3    성남시   911628  141.820
# 4    부천시   805473   53.440
# 5    안산시   668089  144.780
# 6   남양주시   610300  458.440
# 7    안양시   566558   58.520
# 8    화성시   555129  688.100
# 9    평택시   423763  452.310
# 10  의정부시   408220   81.590
# 11   파주시   385528  672.560
# 12   시흥시   381412  134.400
# 13   광명시   327111   38.500
# 14   김포시   326523  276.640
# 15   광주시   290210  431.840
# 16   군포시   273302   36.350
# 17   오산시   200793   42.740
# 18   양주시   191266  310.310
# 19   이천시   190537  461.020
# 20   구리시   175676   33.300
# 21   안성시   173061  554.200
# 22   하남시   150061   93.100
# 23   의왕시   149080   54.000
# 24   포천시   140159  826.380
# 25   여주시   100669  608.640
# 26   양평군    95614  877.080
# 27  동두천시    90398   95.680
# 28   과천시    63227   35.813
# 29   가평군    53497  843.040
# 30   연천군    41076  695.230

# %%
#gy_df 데이터프레임 객체에 인구수2 라는 새로운 컬럼을 생성, 인구수2 컬럼에는 콤마를 포함하는 값
gy_df['인구수2'] = gy_df['인구수'].map(lambda val:f'{val:,}')
gy_df[['인구수','인구수2']].head()
# Out:
#        인구수       인구수2
# 0  1125461  1,125,461
# 1   955384    955,384
# 2   915005    915,005
# 3   911628    911,628
# 4   805473    805,473

# %%
# gy_df 데이터 프레임객체에 면적2 라는 새로운 컬럼을 생성, 면적2 컬럼에는 소수점 이하 첫째자리 값
gy_df['면적2'] = gy_df['면적'].map(lambda val:f'{val:.1f}')
gy_df[['면적','면적2']].head()
# Out:
#        면적    면적2
# 0  121.09  121.1
# 1  267.33  267.3
# 2  591.50  591.5
# 3  141.82  141.8
# 4   53.44   53.4

# %%
# data['행정구역'] == '경기도' 의 ['행정구역','인구수','면적']  컬럼의 데이터를 면적을 descending 순서대로 출력하기
#경기도에 속한 행정구역명, 인구수, 면적 선택하기 인구수를 descending 순서대로 출력하고 index reset 하여 gy_df 라는 변수에 저장하기

gy_df = data.loc[data['광역시도'] == '경기도',['행정구역','인구수','면적']]\
.sort_values(by='면적',ascending=False).reset_index(drop=True)
gy_df
# Out:
#     행정구역      인구수       면적
# 0    양평군    95614  877.080
# 1    가평군    53497  843.040
# 2    포천시   140159  826.380
# 3    연천군    41076  695.230
# 4    화성시   555129  688.100
# 5    파주시   385528  672.560
# 6    여주시   100669  608.640
# 7    용인시   915005  591.500
# 8    안성시   173061  554.200
# 9    이천시   190537  461.020
# 10  남양주시   610300  458.440
# 11   평택시   423763  452.310
# 12   광주시   290210  431.840
# 13   양주시   191266  310.310
# 14   김포시   326523  276.640
# 15   고양시   955384  267.330
# 16   안산시   668089  144.780
# 17   성남시   911628  141.820
# 18   시흥시   381412  134.400
# 19   수원시  1125461  121.090
# 20  동두천시    90398   95.680
# 21   하남시   150061   93.100
# 22  의정부시   408220   81.590
# 23   안양시   566558   58.520
# 24   의왕시   149080   54.000
# 25   부천시   805473   53.440
# 26   오산시   200793   42.740
# 27   광명시   327111   38.500
# 28   군포시   273302   36.350
# 29   과천시    63227   35.813
# 30   구리시   175676   33.300

# %%
#gy_df 데이터프레임 객체에 인구수2 라는 새로운 컬럼을 생성
# Out:
#     행정구역      인구수       면적       인구수2     면적2
# 0    수원시  1125461  121.090  1,125,461  121.09
# 1    고양시   955384  267.330    955,384  267.33
# 2    용인시   915005  591.500    915,005  591.50
# 3    성남시   911628  141.820    911,628  141.82
# 4    부천시   805473   53.440    805,473   53.44
# 5    안산시   668089  144.780    668,089  144.78
# 6   남양주시   610300  458.440    610,300  458.44
# 7    안양시   566558   58.520    566,558   58.52
# 8    화성시   555129  688.100    555,129  688.10
# 9    평택시   423763  452.310    423,763  452.31
# 10  의정부시   408220   81.590    408,220   81.59
# 11   파주시   385528  672.560    385,528  672.56
# 12   시흥시   381412  134.400    381,412  134.40
# 13   광명시   327111   38.500    327,111   38.50
# 14   김포시   326523  276.640    326,523  276.64
# 15   광주시   290210  431.840    290,210  431.84
# 16   군포시   273302   36.350    273,302   36.35
# 17   오산시   200793   42.740    200,793   42.74
# 18   양주시   191266  310.310    191,266  310.31
# 19   이천시   190537  461.020    190,537  461.02
# 20   구리시   175676   33.300    175,676   33.30
# 21   안성시   173061  554.200    173,061  554.20
# 22   하남시   150061   93.100    150,061   93.10
# 23   의왕시   149080   54.000    149,080   54.00
# 24   포천시   140159  826.380    140,159  826.38
# 25   여주시   100669  608.640    100,669  608.64
# 26   양평군    95614  877.080     95,614  877.08
# 27  동두천시    90398   95.680     90,398   95.68
# 28   과천시    63227   35.813     63,227   35.81
# 29   가평군    53497  843.040     53,497  843.04
# 30   연천군    41076  695.230     41,076  695.23

# %%
# 면적이 > 1000 큰 조건과 매핑되는 새로운 DataFrame 생성 area_1000 라는 변수에 저장하기
area_1000 = data.loc[data['면적']>1000].copy()
area_1000.head()

# area_1000 DataFrame 객체에 면적2 컬럼을 생성
area_1000.loc[:,'면적2']= area_1000['면적'].map('{:,}'.format)
area_1000.loc[:,['면적','면적2']]
# Out:
#          면적       면적2
# 0   1040.07  1,040.07
# 3   1185.80   1,185.8
# 7   1127.36  1,127.36
# 9   1646.08  1,646.08
# 10  1220.67  1,220.67
# 12  1116.35  1,116.35
# 14  1463.65  1,463.65
# 15  1817.94  1,817.94
# 68  1323.85  1,323.85
# 72  1009.56  1,009.56
# 74  1201.00   1,201.0
# 75  1254.82  1,254.82
# 77  1519.00   1,519.0
# 85  1175.89  1,175.89
# 89  1127.00   1,127.0

# %%
#inplace = False 속성(Default)은 원본을 변경하지 않고, 변경한 내용을 출력만 해주는 옵션
#inplace = True 속성은 원본을 변경하고, 변경한 내용을 출력하지 않는 옵션
area_1000.reset_index(drop=True,inplace=False)
# Out:
#     Unnamed: 0     인구수 shortName   x   y       면적  광역시도 행정구역       면적2
# 0            0  202520        강릉  11   4  1040.07   강원도  강릉시  1,040.07
# 1            3   63986        삼척  11   8  1185.80   강원도  삼척시   1,185.8
# 2            7   34966        영월  10   8  1127.36   강원도  영월군  1,127.36
# 3            9   29260        인제   9   2  1646.08   강원도  인제군  1,646.08
# 4           10   34242        정선  11   6  1220.67   강원도  정선군  1,220.67
# 5           12  264144        춘천  10   3  1116.35   강원도  춘천시  1,116.35
# 6           14   38439        평창  10   6  1463.65   강원도  평창군  1,463.65
# 7           15   62957        홍천  10   4  1817.94   강원도  홍천군  1,817.94
# 8           68  242618        경주  12  12  1323.85  경상북도  경주시  1,323.85
# 9           72  127941        김천   8  11  1009.56  경상북도  김천시  1,009.56
# 10          74   30287        봉화  11   9  1201.00  경상북도  봉화군   1,201.0
# 11          75   93305        상주   8   9  1254.82  경상북도  상주시  1,254.82
# 12          77  157317        안동  10  10  1519.00  경상북도  안동시   1,519.0
# 13          85   48776        의성  10  11  1175.89  경상북도  의성군  1,175.89
# 14          89  488395        포항  12  11  1127.00  경상북도  포항시   1,127.0

# %%
area_1000.head()
# Out:
#     Unnamed: 0     인구수 shortName   x  y       면적 광역시도 행정구역       면적2
# 0            0  202520        강릉  11  4  1040.07  강원도  강릉시  1,040.07
# 3            3   63986        삼척  11  8  1185.80  강원도  삼척시   1,185.8
# 7            7   34966        영월  10  8  1127.36  강원도  영월군  1,127.36
# 9            9   29260        인제   9  2  1646.08  강원도  인제군  1,646.08
# 10          10   34242        정선  11  6  1220.67  강원도  정선군  1,220.67

# %%
# 면적 컬럼의 값이 1500인 Row에만 면적3 이라는 새로운 컬럼의 값이 채워지고
# 조건에 해당하지 않는 Row에는 NaN 값으로 채워진다.
area_1000.loc[area_1000['면적'] >= 1500,'면적3'] = area_1000['면적'].map('{:,}'.format)

# %%
area_1000.loc[:,['면적','면적2','면적3']].sort_values(by='면적',ascending=False)
# Out:
#          면적       면적2       면적3
# 15  1817.94  1,817.94  1,817.94
# 9   1646.08  1,646.08  1,646.08
# 77  1519.00   1,519.0   1,519.0
# 14  1463.65  1,463.65       NaN
# 68  1323.85  1,323.85       NaN
# 75  1254.82  1,254.82       NaN
# 10  1220.67  1,220.67       NaN
# 74  1201.00   1,201.0       NaN
# 3   1185.80   1,185.8       NaN
# 85  1175.89  1,175.89       NaN
# 7   1127.36  1,127.36       NaN
# 89  1127.00   1,127.0       NaN
# 12  1116.35  1,116.35       NaN
# 0   1040.07  1,040.07       NaN
# 72  1009.56  1,009.56       NaN

# %%
#경기도 인구수의 평균과 표준편차
#경기도 인구수의 평균과 표준편차
print(f"경기도 인구수 평균 = {gy_df['인구수'].mean()}")
print(f"경기도 인구수 편차 = {gy_df['인구수'].std()}")
# Out:
# 경기도 인구수 평균 = 378845.48387096776
# 경기도 인구수 편차 = 304548.39514203876

# %%
#광역시도명을 인자로 받아서 해당 광역시에 속한 행정구역들의 인구수의 평균과 편차 구하기
def pop_mean_std(df, sido_name):
    print(f'==> {sido_name} 인구수의 평균과 편차 <==')
    sido_df = df.loc[df['광역시도'] == sido_name,'인구수':'행정구역'].copy()
    print(f"{sido_name} 인구수 평균 = {sido_df['인구수'].mean()}")
    print(f"{sido_name} 인구수 편차 = {sido_df['인구수'].std()}")

# %%
pop_mean_std(data, '서울특별시')
# Out:
# ==> 서울특별시 인구수의 평균과 편차 <==
# 서울특별시 인구수 평균 = 375792.28
# 서울특별시 인구수 편차 = 125231.24797500289

# %%
# Unique한 광역시도명 순회하면서  광역시도명을 출력합니다. 
for sido_name in data['광역시도'].unique():
    pop_mean_std(data, sido_name)
    print('-----------------------')
# Out:
# ==> 강원도 인구수의 평균과 편차 <==
# 강원도 인구수 평균 = 79413.22222222222
# 강원도 인구수 편차 = 87316.38323837094
# -----------------------
# ==> 경기도 인구수의 평균과 편차 <==
# 경기도 인구수 평균 = 378845.48387096776
# 경기도 인구수 편차 = 304548.3951420388
# -----------------------
# ==> 경상남도 인구수의 평균과 편차 <==
# 경상남도 인구수 평균 = 174693.72222222222
# 경상남도 인구수 편차 = 245796.4650767224
# -----------------------
# ==> 경상북도 인구수의 평균과 편차 <==
# 경상북도 인구수 평균 = 109085.39130434782
# 경상북도 인구수 편차 = 124954.74088490059
# -----------------------
# ==> 광주광역시 인구수의 평균과 편차 <==
# 광주광역시 인구수 평균 = 287641.8
# 광주광역시 인구수 편차 = 137076.68320578814
# -----------------------
# ==> 대구광역시 인구수의 평균과 편차 <==
# 대구광역시 인구수 평균 = 297306.25
# 대구광역시 인구수 편차 = 174375.39437968715
# -----------------------
# ==> 대전광역시 인구수의 평균과 편차 <==
# 대전광역시 인구수 평균 = 293535.4
# 대전광역시 인구수 편차 = 111853.57188217103
# -----------------------
# ==> 부산광역시 인구수의 평균과 편차 <==
# 부산광역시 인구수 평균 = 207724.4375
# 부산광역시 인구수 편차 = 106246.04138380481
# -----------------------
# ==> 서울특별시 인구수의 평균과 편차 <==
# 서울특별시 인구수 평균 = 375792.28
# 서울특별시 인구수 편차 = 125231.24797500289
# -----------------------
# ==> 세종특별자치시 인구수의 평균과 편차 <==
# 세종특별자치시 인구수 평균 = 191233.0
# 세종특별자치시 인구수 편차 = nan
# -----------------------
# ==> 울산광역시 인구수의 평균과 편차 <==
# 울산광역시 인구수 평균 = 221117.0
# 울산광역시 인구수 편차 = 64163.28658196991
# -----------------------
# ==> 인천광역시 인구수의 평균과 편차 <==
# 인천광역시 인구수 평균 = 276657.5
# 인천광역시 인구수 편차 = 199353.5964908417
# -----------------------
# ==> 전라남도 인구수의 평균과 편차 <==
# 전라남도 인구수 평균 = 77298.31818181818
# 전라남도 인구수 편차 = 74413.25322969876
# -----------------------
# ==> 전라북도 인구수의 평균과 편차 <==
# 전라북도 인구수 평균 = 124217.71428571429
# 전라북도 인구수 편차 = 168327.13482128442
# -----------------------
# ==> 제주특별자치도 인구수의 평균과 편차 <==
# 제주특별자치도 인구수 평균 = 287936.5
# 제주특별자치도 인구수 편차 = 201620.89205362622
# -----------------------
# ==> 충청남도 인구수의 평균과 편차 <==
# 충청남도 인구수 평균 = 129741.93333333333
# 충청남도 인구수 편차 = 141125.1080796583
# -----------------------
# ==> 충청북도 인구수의 평균과 편차 <==
# 충청북도 인구수 평균 = 134974.54545454544
# 충청북도 인구수 편차 = 223460.35665744546
# -----------------------

# %%
#loc[] 사용
#인덱스가 20 부터 25까지
data.loc[20:25]
# Out:
#     Unnamed: 0     인구수 shortName  x  y       면적 광역시도 행정구역
# 20          20   63227        과천  7  7   35.813  경기도  과천시
# 21          21  327111        광명  3  3   38.500  경기도  광명시
# 22          22  290210        광주  8  7  431.840  경기도  광주시
# 23          23  175676        구리  9  4   33.300  경기도  구리시
# 24          24  273302        군포  5  8   36.350  경기도  군포시
# 25          25  326523        김포  2  3  276.640  경기도  김포시

# %%
#iloc[] 사용
#인덱스가 20 부터 24까지// 인덱스라서 25포함 안됨!
data.iloc[20:25]
# Out:
#     Unnamed: 0     인구수 shortName  x  y       면적 광역시도 행정구역
# 20          20   63227        과천  7  7   35.813  경기도  과천시
# 21          21  327111        광명  3  3   38.500  경기도  광명시
# 22          22  290210        광주  8  7  431.840  경기도  광주시
# 23          23  175676        구리  9  4   33.300  경기도  구리시
# 24          24  273302        군포  5  8   36.350  경기도  군포시

# %%
data.columns
# Out:
# Index(['Unnamed: 0', '인구수', 'shortName', 'x', 'y', '면적', '광역시도', '행정구역'], dtype='str')

# %%
#iloc[row index, column index] 사용 
#인덱스가 20 부터 25까지 컬럼이 인구수부터 행정구역 까지
data.iloc[20:25,1:8]
# Out:
#        인구수 shortName  x  y       면적 광역시도 행정구역
# 20   63227        과천  7  7   35.813  경기도  과천시
# 21  327111        광명  3  3   38.500  경기도  광명시
# 22  290210        광주  8  7  431.840  경기도  광주시
# 23  175676        구리  9  4   33.300  경기도  구리시
# 24  273302        군포  5  8   36.350  경기도  군포시

# %%
#loc[] 사용
#index가 40,55,60 이고, column이 인구수,광역시도,행정구역
data.loc[[40,55,60],['인구수','광역시도','행정구역']]
# Out:
#        인구수  광역시도 행정구역
# 40  915005   경기도  용인시
# 55  106388  경상남도  사천시
# 60   56734  경상남도  창녕군

# %%
#인덱스가 0인 행 하나만 선택
print(type(data.loc[0]))
data.loc[0]
# Out:
# <class 'pandas.core.series.Series'>
# Unnamed: 0          0
# 인구수            202520
# shortName          강릉
# x                  11
# y                   4
# 면적            1040.07
# 광역시도              강원도
# 행정구역              강릉시
# Name: 0, dtype: object

# %%
#열 하나만 선택
print(type(data['행정구역']))
data['행정구역'].head()
# Out:
# <class 'pandas.core.series.Series'>
# 0    1040.07
# 1     664.19
# 2     180.01
# 3    1185.80
# 4     105.25
# Name: 면적, dtype: float64

# %% [markdown]
# ### 컬럼명 변경하기, 컬럼을 인덱스 전환하기
# * rename() 함수
# * inPlace=False (default) 원본 DataFrame객체를 변경하지 않고, 변경한 결과만 출력한다.
# * inPlace=True 원본 DataFrame객체를 변경하고, 변경한 결과는 출력하지 않는다.

# %%
data.columns
# Out:
# Index(['Unnamed: 0', '인구수', 'shortName', 'x', 'y', '면적', '광역시도', '행정구역'], dtype='object')

# %%
# 'Unnamed: 0' 컬럼명을 'seq' 로 변경한다. 원본 객체는 변경되지 않고 변경된 결과만 출력함
data.rename(columns={'Unnamed: 0':'seq'}, inplace = False)
# Out:
#      seq     인구수 shortName   x   y       면적  광역시도 행정구역
# 0      0  202520        강릉  11   4  1040.07   강원도  강릉시
# 1      1   25589    고성(강원)   9   0   664.19   강원도  고성군
# 2      2   86747        동해  11   5   180.01   강원도  동해시
# 3      3   63986        삼척  11   8  1185.80   강원도  삼척시
# 4      4   76733        속초   9   1   105.25   강원도  속초시
# ..   ...     ...       ...  ..  ..      ...   ...  ...
# 224  224  127462        제천   8  10   882.47  충청북도  제천시
# 225  225   34480        증평   6  11    81.84  충청북도  증평군
# 226  226   62809        진천   5  11   406.08  충청북도  진천군
# 227  227  790216        청주   6  12   932.51  충청북도  청주시
# 228  228  198077        충주   6  10   983.70  충청북도  충주시
#
# [229 rows x 8 columns]

# %%
#원본 객체가 변경되고 변경된 결과는 출력하지 않는다.

data.rename(columns={'Unnamed: 0':'seq'}, inplace = True)
# Out:
# Index(['seq', '인구수', 'shortName', 'x', 'y', '면적', '광역시도', '행정구역'], dtype='object')

# %%
# seq 컬럼을 인덱스로 변경한다 ( 원본 객체가 변경됨 )
data.head()

# %% [markdown]
# ### DataFrame을 Excel file로 저장하기
# * 인구수가 평균보다 작은 행정구역, 광역시도, 인구수를 선택해서 DataFrame생성하기
# * DataFrame의 to_excel() 함수 사용

# %%
# 인구수의 평균값 구하기
pop_mean_value=data['인구수'].mean()
print(pop_mean_value)
print(round(pop_mean_value))
print(f'{pop_mean_value:.2f}')
# Out:
# 211089.77729257641
# 211090
# 211089.78

# %%
# 인구수의 평균값보다 작은 Row를 선택하고, '광역시도','행정구역','인구수' 컬럼값을 가져오기
# 정렬할때 광역시도는 ascending으로 , 인구수는 descending
pop_mean_lt_df = data.loc[data['인구수'] < pop_mean_value, ['광역시도','행정구역','인구수']]\
.sort_values(by=['광역시도','인구수'],ascending=[True,False])\
.reset_index(drop=True)

# %%
print(type(pop_mean_lt_df))
print(pop_mean_lt_df.shape)
pop_mean_lt_df.head()
# Out:
# <class 'pandas.DataFrame'>
# (141, 3)
#   광역시도 행정구역     인구수
# 0  강원도  강릉시  202520
# 1  강원도  동해시   86747
# 2  강원도  속초시   76733
# 3  강원도  삼척시   63986
# 4  강원도  홍천군   62957

# %%
# DataFrame의 to_excel() 함수를 사용하여 excel 파일로 저장
pop_mean_lt_df.to_excel('data/평균인구수미만행정구역.xlsx')

# %% [markdown]
# ### GroupBy 기능 사용하기
# * 광역시도별 행정구역의 인구수 합계
# * ~별에 해당하는 컬럼명이나 컬럼값을 groupby() 함수의 인자로 전달한다.
# * Series 객체의 groupby(data['광역시도']) 함수는 컬럼의 값을 인자로 전달하고
# * DataFrame 객체의 groupby('광역시도') 함수는 컬럼명을 인자로 전달합니다.

# %%
# Series 객체 사용 - 광역시도별 인구수의 합계 
# SeriesGroupBy object
data['인구수'].groupby(data['광역시도']).sum()
# Out:
# 광역시도
# 강원도         1429438
# 경기도        11744210
# 경상남도        3144487
# 경상북도        2508964
# 광주광역시       1438209
# 대구광역시       2378450
# 대전광역시       1467677
# 부산광역시       3323591
# 서울특별시       9394807
# 세종특별자치시      191233
# 울산광역시       1105585
# 인천광역시       2766575
# 전라남도        1700563
# 전라북도        1739048
# 제주특별자치도      575873
# 충청남도        1946129
# 충청북도        1484720
# Name: 인구수, dtype: int64

# %%
# DataFrame 객체 사용 - 광역시도별 인구수의 합계 
# DataFrameGroupBy object
data.groupby('광역시도').sum(numeric_only=True)
# Out:
#          Unnamed: 0       인구수    x    y         면적
# 광역시도
# 강원도             153   1429438  173   68  16874.810
# 경기도            1023  11744210  182  162  10179.743
# 경상남도           1035   3144487  123  313  10437.460
# 경상북도           1794   2508964  229  240  19021.850
# 광주광역시           460   1438209   12   99    501.280
# 대구광역시           788   2378450   74  111    885.690
# 대전광역시           525   1467677   23   66    539.640
# 부산광역시          1848   3323591  162  276    763.240
# 서울특별시          3400   9394807  142  111    605.390
# 세종특별자치시         149    191233    4   11    465.230
# 울산광역시           760   1105585   58   71    980.220
# 인천광역시          1595   2766575   13   61   1022.910
# 전라남도           3861   1700563   44  438  12008.390
# 전라북도           2709   1739048   46  219   7907.220
# 제주특별자치도         403    575873    8   49   1848.480
# 충청남도           3150   1946129   39  160   8272.270
# 충청북도           2453   1484720   69  124   7397.310

# %%
# DataFrameGroupBy 
data.groupby('광역시도')['인구수'].sum()
# Out:
# 광역시도
# 강원도         1429438
# 경기도        11744210
# 경상남도        3144487
# 경상북도        2508964
# 광주광역시       1438209
# 대구광역시       2378450
# 대전광역시       1467677
# 부산광역시       3323591
# 서울특별시       9394807
# 세종특별자치시      191233
# 울산광역시       1105585
# 인천광역시       2766575
# 전라남도        1700563
# 전라북도        1739048
# 제주특별자치도      575873
# 충청남도        1946129
# 충청북도        1484720
# Name: 인구수, dtype: int64

# %%
# 광역시도별 행정구역별 인구수의 합계
data.groupby(['광역시도','행정구역'])['인구수'].sum()
# Out:
# 광역시도  행정구역
# 강원도   강릉시     202520
#       고성군      25589
#       동해시      86747
#       삼척시      63986
#       속초시      76733
#                ...
# 충청북도  제천시     127462
#       증평군      34480
#       진천군      62809
#       청주시     790216
#       충주시     198077
# Name: 인구수, Length: 229, dtype: int64

# %%
# data/광역시도별행정구역별인구수의합계.xlsx 파일로 저장하기
group_df = data.groupby(['광역시도','행정구역'])['인구수'].sum()
group_df.to_excel('data/광역시도별행정구역별인구수합계.xlsx',sheet_name='인구수합계')

# %% [markdown]
# ### 엑셀 수치 데이터에 콤마찍기
# [pandas.ExcelWriter](https://pandas.pydata.org/docs/reference/api/pandas.ExcelWriter.html)

# %%
# %pip install xlsxwriter
# Out:
# Collecting xlsxwriter
#   Downloading xlsxwriter-3.2.9-py3-none-any.whl.metadata (2.7 kB)
# Downloading xlsxwriter-3.2.9-py3-none-any.whl (175 kB)
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.2.9
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('data/광역시도별인구수의합계1.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
group_df.to_excel(writer, sheet_name='인구수합계')

# Get the xlsxwriter workbook and worksheet objects.
workbook  = writer.book
worksheet = writer.sheets['인구수합계']

# Set a currency number format for a column.
num_format = workbook.add_format({'num_format': '#,###'})
worksheet.set_column('C:C', None, num_format)

# Close the Pandas Excel writer and output the Excel file.
writer.close() #_save()

# %% [markdown]
# #### 상관계수 (Correlation Coefficient)
# * 인구수와 면적 데이터간에 관련성이 있는지 살펴보기 위해서 상관계수 구하기
# * 상관계수 값은 -1 ~ 1 사이의 값이며, 0에 가까울 수록 관련성이 낮고, 1에 가까울 수록 관련성이 높다.
# * 음수는 반비례 (면적이 넓은 반면 인구수는 적은 경우), 양수는 비례 (면적이 넓고, 인구수도 높은 경우)
# * corr() 함수

# %%
#전국의 면적과 인구수의 상관계수 구하기
data['면적'].corr(data['인구수'])
# Out:
# np.float64(-0.346035160504577)

# %%
#서울의 면적과 인구수의 상관계수 구하기
seoul_df = data.loc[data['광역시도'] == '서울특별시',['행정구역','인구수','면적']].copy()
seoul_df['면적'].corr(seoul_df['인구수'])
# Out:
# np.float64(0.6644268188909778)

# %%
#경기도의 면적과 인구수의 상관계수 구하기
gy_df['면적'].corr(gy_df['인구수'])
# Out:
# -0.21572485071590813

# %%
for sido_name in data['광역시도'].unique():
    print(f'{sido_name} 인구수와면적간의 상관계수 = ')
    sido_df = data.loc[data['광역시도'] == sido_name,['행정구역','인구수','면적']]
    print(sido_df['면적'].corr(sido_df['인구수']))
# Out:
# 강원도 인구수와면적간의 상관계수 =
# -0.003424870292108486
# 경기도 인구수와면적간의 상관계수 =
# -0.21572485071590813
# 경상남도 인구수와면적간의 상관계수 =
# 0.029951565364477125
# 경상북도 인구수와면적간의 상관계수 =
# 0.20592950800967932
# 광주광역시 인구수와면적간의 상관계수 =
# 0.6769289677125123
# 대구광역시 인구수와면적간의 상관계수 =
# -0.057946386652948614
# 대전광역시 인구수와면적간의 상관계수 =
# 0.1997155244648549
# 부산광역시 인구수와면적간의 상관계수 =
# -0.13823708369604065
# 서울특별시 인구수와면적간의 상관계수 =
# 0.6644268188909778
# 세종특별자치시 인구수와면적간의 상관계수 =
# nan
# 울산광역시 인구수와면적간의 상관계수 =
# -0.13435717195061844
# 인천광역시 인구수와면적간의 상관계수 =
# -0.4571430756049645
# 전라남도 인구수와면적간의 상관계수 =
# -0.05786859599072531
# 전라북도 인구수와면적간의 상관계수 =
# -0.695805033826725
# 제주특별자치도 인구수와면적간의 상관계수 =
# 1.0
# 충청남도 인구수와면적간의 상관계수 =
# 0.2729636767632082
# 충청북도 인구수와면적간의 상관계수 =
# 0.4110669104748176
# c:\Users\User.DESKTOP-G5S2APU\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\_function_base_impl.py:3028: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# c:\Users\User.DESKTOP-G5S2APU\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\_function_base_impl.py:2901: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# c:\Users\User.DESKTOP-G5S2APU\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\_function_base_impl.py:2901: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)

# %% [markdown]
# #### Groupby 한 DataFrame에 집계함수를 여러개 설정하기
# * agg() 함수
# * agg(['max','mean','std'])

# %%
# agg() 함수 사용하여 여러개의 통계함수를 사용합니다. 
# fillna(0) NaN 을 0 으로 변경해 줌
data.groupby('광역시도')['인구수'].agg(['max','mean','std'])
# Out:
#              max           mean            std
# 광역시도
# 강원도       313851   79413.222222   87316.383238
# 경기도      1125461  378845.483871  304548.395142
# 경상남도     1010040  174693.722222  245796.465077
# 경상북도      488395  109085.391304  124954.740885
# 광주광역시     439683  287641.800000  137076.683206
# 대구광역시     584517  297306.250000  174375.394380
# 대전광역시     475094  293535.400000  111853.571882
# 부산광역시     397134  207724.437500  106246.041384
# 서울특별시     615487  375792.280000  125231.247975
# 세종특별자치시   191233  191233.000000            NaN
# 울산광역시     327270  221117.000000   64163.286582
# 인천광역시     527153  276657.500000  199353.596491
# 전라남도      263166   77298.318182   74413.253230
# 전라북도      630708  124217.714286  168327.134821
# 제주특별자치도   430504  287936.500000  201620.892054
# 충청남도      584912  129741.933333  141125.108080
# 충청북도      790216  134974.545455  223460.356657

# %%
# agg() 함수 사용 - 그룹핑한 데이터를 여러개의 집계함수를 사용해서 새로운 DataFrame 객체 생성하기
# agg() 함수 사용 - 그룹핑한 데이터를 여러개의 집계함수를 사용해서 새로운 DataFrame 객체 생성하기
group_agg_df = data.groupby('광역시도')['인구수'].agg(['max','mean','std']).fillna(0)
group_agg_df.sort_values(by='std', ascending=False)
# Out:
#              max           mean            std
# 광역시도
# 경기도      1125461  378845.483871  304548.395142
# 경상남도     1010040  174693.722222  245796.465077
# 충청북도      790216  134974.545455  223460.356657
# 제주특별자치도   430504  287936.500000  201620.892054
# 인천광역시     527153  276657.500000  199353.596491
# 대구광역시     584517  297306.250000  174375.394380
# 전라북도      630708  124217.714286  168327.134821
# 충청남도      584912  129741.933333  141125.108080
# 광주광역시     439683  287641.800000  137076.683206
# 서울특별시     615487  375792.280000  125231.247975
# 경상북도      488395  109085.391304  124954.740885
# 대전광역시     475094  293535.400000  111853.571882
# 부산광역시     397134  207724.437500  106246.041384
# 강원도       313851   79413.222222   87316.383238
# 전라남도      263166   77298.318182   74413.253230
# 울산광역시     327270  221117.000000   64163.286582
# 세종특별자치시   191233  191233.000000       0.000000

# %%
group_agg_df.style.format('{0:.2f}')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 group_agg_df.style.format('{0:.2f}')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6194, in NDFrame.__getattr__(self, name)
#    6187 if (
#    6188     name not in self._internal_names_set
#    6189     and name not in self._metadata
#    6190     and name not in self._accessors
#    6191     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6192 ):
#    6193     return self[name]
# -> 6194 return object.__getattribute__(self, name)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:1430, in DataFrame.style(self)
#    1428 has_jinja2 = import_optional_dependency("jinja2", errors="ignore")
#    1429 if not has_jinja2:
# -> 1430     raise AttributeError("The '.style' accessor requires jinja2")
#    1432 from pandas.io.formats.style import Styler
#    1434 return Styler(self)
#
# AttributeError: The '.style' accessor requires jinja2

# %%
# 컬럼의 값을 변경하기 map() 함수를 사용하여 포맷하기
group_agg_df['mean'] = group_agg_df['mean'].map('{:.2f}'.format)
group_agg_df['std'] = group_agg_df['std'].map('{:.2f}'.format)

# %% [markdown]
# #### 시각화
# * %matplotlib inline 설정 (jupyter 에서는 show() 함수를 호출하지 않아도 plot이 출력된다)
# * 한글폰트 설정이 필요함
# * Plot에 대한 설정은 matplotlib의 함수를 사용하고, Plot을 그려주는 기능은 seaborn()의 함수를 사용합니다.

# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns

print('matplotlib ', matplotlib.__version__)
print('seaborn ', sns.__version__)
# Out:
# matplotlib  3.11.1
# seaborn  0.13.2

# %%
# for font in fm.fontManager.ttflist:
#     print((font.name, font.fname))
# 폰트이름과 폰트파일 정보 출력 list comprehension 
[ (font.name, font.fname) for font in fm.fontManager.ttflist]# if 'Mal' in font.name ]
# Out:
# [('cmss10',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\cmss10.ttf'),
#  ('DejaVu Sans',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans.ttf'),
#  ('DejaVu Serif Display',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSerifDisplay.ttf'),
#  ('STIXNonUnicode',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXNonUniBol.ttf'),
#  ('STIXNonUnicode',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXNonUni.ttf'),
#  ('DejaVu Serif',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSerif-Italic.ttf'),
#  ('STIXGeneral',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXGeneralBol.ttf'),
#  ('DejaVu Sans Mono',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSansMono-BoldOblique.ttf'),
#  ('STIXGeneral',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXGeneral.ttf'),
#  ('DejaVu Sans Mono',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSansMono-Oblique.ttf'),
#  ('STIXSizeTwoSym',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXSizTwoSymReg.ttf'),
#  ('STIXSizeFourSym',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXSizFourSymBol.ttf'),
#  ('cmr10',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\cmr10.ttf'),
#  ('DejaVu Sans Display',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSansDisplay.ttf'),
#  ('STIXSizeOneSym',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXSizOneSymBol.ttf'),
#  ('STIXGeneral',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXGeneralBolIta.ttf'),
#  ('cmb10',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\cmb10.ttf'),
#  ('cmmi10',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\cmmi10.ttf'),
#  ('STIXNonUnicode',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXNonUniIta.ttf'),
#  ('STIXNonUnicode',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXNonUniBolIta.ttf'),
#  ('DejaVu Serif',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSerif-BoldItalic.ttf'),
#  ('STIXSizeThreeSym',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXSizThreeSymBol.ttf'),
#  ('DejaVu Serif',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSerif-Bold.ttf'),
#  ('Last Resort High-Efficiency',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\LastResortHE-Regular.ttf'),
#  ('DejaVu Sans Mono',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSansMono-Bold.ttf'),
#  ('DejaVu Sans',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans-Bold.ttf'),
#  ('DejaVu Sans Mono',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSansMono.ttf'),
#  ('STIXSizeFourSym',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXSizFourSymReg.ttf'),
#  ('STIXSizeOneSym',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXSizOneSymReg.ttf'),
#  ('DejaVu Sans',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans-Oblique.ttf'),
#  ('STIXGeneral',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXGeneralItalic.ttf'),
#  ('cmtt10',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\cmtt10.ttf'),
#  ('STIXSizeTwoSym',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXSizTwoSymBol.ttf'),
#  ('STIXSizeThreeSym',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXSizThreeSymReg.ttf'),
#  ('cmti10',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\cmti10.ttf'),
#  ('STIXSizeFiveSym',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXSizFiveSymReg.ttf'),
#  ('DejaVu Serif',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSerif.ttf'),
#  ('cmex10',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\cmex10.ttf'),
#  ('DejaVu Sans',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans-BoldOblique.ttf'),
#  ('cmsy10',
#   'c:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\cmsy10.ttf'),
#  ('Script MT Bold', 'C:\\Windows\\Fonts\\SCRIPTBL.TTF'),
#  ('Webdings', 'C:\\Windows\\Fonts\\webdings.ttf'),
#  ('Eras Demi ITC', 'C:\\Windows\\Fonts\\ERASDEMI.TTF'),
#  ('OpenSymbol', 'C:\\Windows\\Fonts\\opens___.ttf'),
#  ('DejaVu Serif', 'C:\\Windows\\Fonts\\DejaVuSerifCondensed.ttf'),
#  ('DejaVu Serif Condensed', 'C:\\Windows\\Fonts\\DejaVuSerifCondensed.ttf'),
#  ('Symbol', 'C:\\Windows\\Fonts\\symbol.ttf'),
#  ('Candara', 'C:\\Windows\\Fonts\\Candarab.ttf'),
#  ('Trebuchet MS', 'C:\\Windows\\Fonts\\trebucit.ttf'),
#  ('Engravers MT', 'C:\\Windows\\Fonts\\ENGR.TTF'),
#  ('Comic Sans MS', 'C:\\Windows\\Fonts\\comici.ttf'),
#  ('Bodoni MT', 'C:\\Windows\\Fonts\\BOD_B.TTF'),
#  ('Arial', 'C:\\Windows\\Fonts\\ARIALNBI.TTF'),
#  ('Arial Narrow', 'C:\\Windows\\Fonts\\ARIALNBI.TTF'),
#  ('Amiri', 'C:\\Windows\\Fonts\\Amiri-Italic.ttf'),
#  ('Gigi', 'C:\\Windows\\Fonts\\GIGI.TTF'),
#  ('Franklin Gothic Book', 'C:\\Windows\\Fonts\\FRABKIT.TTF'),
#  ('Curlz MT', 'C:\\Windows\\Fonts\\CURLZ___.TTF'),
#  ('Gadugi', 'C:\\Windows\\Fonts\\gadugib.ttf'),
#  ('Noto Sans', 'C:\\Windows\\Fonts\\NotoSans-Light.ttf'),
#  ('Noto Sans Light', 'C:\\Windows\\Fonts\\NotoSans-Light.ttf'),
#  ('Gentium Basic', 'C:\\Windows\\Fonts\\GenBasR.ttf'),
#  ('Leelawadee UI', 'C:\\Windows\\Fonts\\LeelawUI.ttf'),
#  ('Noto Sans', 'C:\\Windows\\Fonts\\NotoSans-Italic.ttf'),
#  ('Candara', 'C:\\Windows\\Fonts\\Candarali.ttf'),
#  ('Candara Light', 'C:\\Windows\\Fonts\\Candarali.ttf'),
#  ('HYSinMyeongJo-Medium', 'C:\\Windows\\Fonts\\H2MJSM.TTF'),
#  ('Noto Kufi Arabic', 'C:\\Windows\\Fonts\\NotoKufiArabic-Regular.ttf'),
#  ('David CLM', 'C:\\Windows\\Fonts\\DavidCLM-Medium.otf'),
#  ('Liberation Sans', 'C:\\Windows\\Fonts\\LiberationSans-Bold.ttf'),
#  ('MV Boli', 'C:\\Windows\\Fonts\\mvboli.ttf'),
#  ('Liberation Sans Narrow',
#   'C:\\Windows\\Fonts\\LiberationSansNarrow-Italic.ttf'),
#  ('Gulim', 'C:\\Windows\\Fonts\\gulim.ttc'),
#  ('GulimChe', 'C:\\Windows\\Fonts\\gulim.ttc'),
#  ('Dotum', 'C:\\Windows\\Fonts\\gulim.ttc'),
#  ('DotumChe', 'C:\\Windows\\Fonts\\gulim.ttc'),
#  ('Noto Serif', 'C:\\Windows\\Fonts\\NotoSerif-Bold.ttf'),
#  ('Frank Ruehl CLM', 'C:\\Windows\\Fonts\\FrankRuehlCLM-Bold.ttf'),
#  ('Bodoni MT', 'C:\\Windows\\Fonts\\BOD_BLAR.TTF'),
#  ('Bodoni MT Black', 'C:\\Windows\\Fonts\\BOD_BLAR.TTF'),
#  ('HYHeadLine-Medium', 'C:\\Windows\\Fonts\\H2HDRM.TTF'),
#  ('Perpetua Titling MT', 'C:\\Windows\\Fonts\\PERTILI.TTF'),
#  ('Tw Cen MT Condensed Extra Bold', 'C:\\Windows\\Fonts\\TCCEB.TTF'),
#  ('Noto Serif Georgian', 'C:\\Windows\\Fonts\\NotoSerifGeorgian-Bold.ttf'),
#  ('Sitka', 'C:\\Windows\\Fonts\\SitkaVF-Italic.ttf'),
#  ('Sitka Text', 'C:\\Windows\\Fonts\\SitkaVF-Italic.ttf'),
#  ('Gill Sans MT', 'C:\\Windows\\Fonts\\GILBI___.TTF'),
#  ('Lucida Fax', 'C:\\Windows\\Fonts\\LFAX.TTF'),
#  ('Century Schoolbook', 'C:\\Windows\\Fonts\\SCHLBKBI.TTF'),
#  ('Nirmala UI', 'C:\\Windows\\Fonts\\Nirmala.ttc'),
#  ('Nirmala UI', 'C:\\Windows\\Fonts\\Nirmala.ttc'),
#  ('Nirmala UI', 'C:\\Windows\\Fonts\\Nirmala.ttc'),
#  ('Nirmala UI Semilight', 'C:\\Windows\\Fonts\\Nirmala.ttc'),
#  ('Nirmala Text', 'C:\\Windows\\Fonts\\Nirmala.ttc'),
#  ('Nirmala Text', 'C:\\Windows\\Fonts\\Nirmala.ttc'),
#  ('Nirmala Text', 'C:\\Windows\\Fonts\\Nirmala.ttc'),
#  ('Nirmala Text Semilight', 'C:\\Windows\\Fonts\\Nirmala.ttc'),
#  ('Goudy Old Style', 'C:\\Windows\\Fonts\\GOUDOS.TTF'),
#  ('DejaVu Sans', 'C:\\Windows\\Fonts\\DejaVuSans-Oblique.ttf'),
#  ('Noto Sans', 'C:\\Windows\\Fonts\\NotoSans-CondensedItalic.ttf'),
#  ('Noto Sans Cond', 'C:\\Windows\\Fonts\\NotoSans-CondensedItalic.ttf'),
#  ('Haan Wing2', 'C:\\Windows\\Fonts\\HANWing2.ttf'),
#  ('Hancom Gothic', 'C:\\Windows\\Fonts\\Hancom Gothic Regular.ttf'),
#  ('Caladea', 'C:\\Windows\\Fonts\\Caladea-Regular.ttf'),
#  ('Franklin Gothic Demi Cond', 'C:\\Windows\\Fonts\\FRADMCN.TTF'),
#  ('Tahoma', 'C:\\Windows\\Fonts\\tahoma.ttf'),
#  ('Monotype Corsiva', 'C:\\Windows\\Fonts\\MTCORSVA.TTF'),
#  ('DejaVu Serif', 'C:\\Windows\\Fonts\\DejaVuSerif-Bold.ttf'),
#  ('Noto Serif', 'C:\\Windows\\Fonts\\NotoSerif-CondensedBoldItalic.ttf'),
#  ('Noto Serif Cond', 'C:\\Windows\\Fonts\\NotoSerif-CondensedBoldItalic.ttf'),
#  ('Segoe Script', 'C:\\Windows\\Fonts\\segoesc.ttf'),
#  ('Bodoni MT', 'C:\\Windows\\Fonts\\BOD_BI.TTF'),
#  ('Noto Serif Hebrew', 'C:\\Windows\\Fonts\\NotoSerifHebrew-Regular.ttf'),
#  ('Microsoft YaHei', 'C:\\Windows\\Fonts\\msyhbd.ttc'),
#  ('Microsoft YaHei UI', 'C:\\Windows\\Fonts\\msyhbd.ttc'),
#  ('Poor Richard', 'C:\\Windows\\Fonts\\POORICH.TTF'),
#  ('Arial', 'C:\\Windows\\Fonts\\arial.ttf'),
#  ('Georgia', 'C:\\Windows\\Fonts\\georgia.ttf'),
#  ('Yu Gothic', 'C:\\Windows\\Fonts\\YuGothR.ttc'),
#  ('Yu Gothic UI', 'C:\\Windows\\Fonts\\YuGothR.ttc'),
#  ('Yu Gothic UI Semilight', 'C:\\Windows\\Fonts\\YuGothR.ttc'),
#  ('Nachlieli CLM', 'C:\\Windows\\Fonts\\NachlieliCLM-BoldOblique.otf'),
#  ('Lucida Sans Typewriter', 'C:\\Windows\\Fonts\\LTYPEBO.TTF'),
#  ('SimSun-ExtB', 'C:\\Windows\\Fonts\\simsunb.ttf'),
#  ('Lucida Sans Typewriter', 'C:\\Windows\\Fonts\\LTYPEB.TTF'),
#  ('Tw Cen MT Condensed', 'C:\\Windows\\Fonts\\TCCB____.TTF'),
#  ('Consolas', 'C:\\Windows\\Fonts\\consolaz.ttf'),
#  ('Gill Sans MT Ext Condensed Bold', 'C:\\Windows\\Fonts\\GLSNECB.TTF'),
#  ('Franklin Gothic Medium Cond', 'C:\\Windows\\Fonts\\FRAMDCN.TTF'),
#  ('Han Santteut Dotum', 'C:\\Windows\\Fonts\\HanSantteutDotum-Regular.ttf'),
#  ('Gill Sans MT', 'C:\\Windows\\Fonts\\GILB____.TTF'),
#  ('Matura MT Script Capitals', 'C:\\Windows\\Fonts\\MATURASC.TTF'),
#  ('Segoe UI', 'C:\\Windows\\Fonts\\segoeuii.ttf'),
#  ('Goudy Old Style', 'C:\\Windows\\Fonts\\GOUDOSI.TTF'),
#  ('Cambria', 'C:\\Windows\\Fonts\\cambriai.ttf'),
#  ('Segoe UI', 'C:\\Windows\\Fonts\\segoeuiz.ttf'),
#  ('Courier New', 'C:\\Windows\\Fonts\\courbd.ttf'),
#  ('Segoe UI', 'C:\\Windows\\Fonts\\seguisli.ttf'),
#  ('Segoe UI Semilight', 'C:\\Windows\\Fonts\\seguisli.ttf'),
#  ('Caladea', 'C:\\Windows\\Fonts\\Caladea-Bold.ttf'),
#  ('Candara', 'C:\\Windows\\Fonts\\Candarai.ttf'),
#  ('Hancom Hoonminjeongeum_V', 'C:\\Windows\\Fonts\\Hancom HMJE_V.ttf'),
#  ('Eras Medium ITC', 'C:\\Windows\\Fonts\\ERASMD.TTF'),
#  ('Berlin Sans FB', 'C:\\Windows\\Fonts\\BRLNSB.TTF'),
#  ('Pyunji R', 'C:\\Windows\\Fonts\\HMFMPYUN.TTF'),
#  ('Microsoft Himalaya', 'C:\\Windows\\Fonts\\himalaya.ttf'),
#  ('Juice ITC', 'C:\\Windows\\Fonts\\JUICE___.TTF'),
#  ('Noto Sans Arabic', 'C:\\Windows\\Fonts\\NotoSansArabic-Bold.ttf'),
#  ('Franklin Gothic Medium', 'C:\\Windows\\Fonts\\framdit.ttf'),
#  ('Arial', 'C:\\Windows\\Fonts\\ariblk.ttf'),
#  ('Arial Black', 'C:\\Windows\\Fonts\\ariblk.ttf'),
#  ('Rockwell', 'C:\\Windows\\Fonts\\ROCK.TTF'),
#  ('Constantia', 'C:\\Windows\\Fonts\\constan.ttf'),
#  ('Frank Ruhl Hofshi', 'C:\\Windows\\Fonts\\FrankRuhlHofshi-Bold.otf'),
#  ('Noto Naskh Arabic', 'C:\\Windows\\Fonts\\NotoNaskhArabic-Regular.ttf'),
#  ('Bernard MT Condensed', 'C:\\Windows\\Fonts\\BERNHC.TTF'),
#  ('Segoe UI', 'C:\\Windows\\Fonts\\seguisb.ttf'),
#  ('Segoe UI Semibold', 'C:\\Windows\\Fonts\\seguisb.ttf'),
#  ('Arial Rounded MT Bold', 'C:\\Windows\\Fonts\\ARLRDBD.TTF'),
#  ('Eras Bold ITC', 'C:\\Windows\\Fonts\\ERASBD.TTF'),
#  ('Noto Sans Lao', 'C:\\Windows\\Fonts\\NotoSansLao-Bold.ttf'),
#  ('Microsoft New Tai Lue', 'C:\\Windows\\Fonts\\ntailu.ttf'),
#  ('Noto Sans', 'C:\\Windows\\Fonts\\NotoSans-LightItalic.ttf'),
#  ('Noto Sans Light', 'C:\\Windows\\Fonts\\NotoSans-LightItalic.ttf'),
#  ('Bodoni MT', 'C:\\Windows\\Fonts\\BOD_CB.TTF'),
#  ('Bodoni MT Condensed', 'C:\\Windows\\Fonts\\BOD_CB.TTF'),
#  ('Gentium Book Basic', 'C:\\Windows\\Fonts\\GenBkBasI.ttf'),
#  ('HYMyeongJo-Extra', 'C:\\Windows\\Fonts\\H2MJRE.TTF'),
#  ('Lucida Sans Typewriter', 'C:\\Windows\\Fonts\\LTYPE.TTF'),
#  ('HyhwpEQ', 'C:\\Windows\\Fonts\\HYHWPEQ.TTF'),
#  ('Papyrus', 'C:\\Windows\\Fonts\\PAPYRUS.TTF'),
#  ('HCR Batang', 'C:\\Windows\\Fonts\\HANBatang.ttf'),
#  ('Century Schoolbook', 'C:\\Windows\\Fonts\\CENSCBK.TTF'),
#  ('Javanese Text', 'C:\\Windows\\Fonts\\javatext.ttf'),
#  ('Miriam Mono CLM', 'C:\\Windows\\Fonts\\MiriamMonoCLM-BookOblique.ttf'),
#  ('HCR Batang', 'C:\\Windows\\Fonts\\HANBatangB.ttf'),
#  ('Informal Roman', 'C:\\Windows\\Fonts\\INFROMAN.TTF'),
#  ('Nachlieli CLM', 'C:\\Windows\\Fonts\\NachlieliCLM-Light.otf'),
#  ('MingLiU-ExtB', 'C:\\Windows\\Fonts\\mingliub.ttc'),
#  ('PMingLiU-ExtB', 'C:\\Windows\\Fonts\\mingliub.ttc'),
#  ('MingLiU_HKSCS-ExtB', 'C:\\Windows\\Fonts\\mingliub.ttc'),
#  ('MingLiU_MSCS-ExtB', 'C:\\Windows\\Fonts\\mingliub.ttc'),
#  ('Microsoft Tai Le', 'C:\\Windows\\Fonts\\taile.ttf'),
#  ('Palatino Linotype', 'C:\\Windows\\Fonts\\palai.ttf'),
#  ('Gentium Basic', 'C:\\Windows\\Fonts\\GenBasBI.ttf'),
#  ('Eras Light ITC', 'C:\\Windows\\Fonts\\ERASLGHT.TTF'),
#  ('Palatino Linotype', 'C:\\Windows\\Fonts\\pala.ttf'),
#  ('Segoe UI', 'C:\\Windows\\Fonts\\segoeuib.ttf'),
#  ('Californian FB', 'C:\\Windows\\Fonts\\CALIFI.TTF'),
#  ('SimSun', 'C:\\Windows\\Fonts\\simsun.ttc'),
#  ('NSimSun', 'C:\\Windows\\Fonts\\simsun.ttc'),
#  ('Rubik', 'C:\\Windows\\Fonts\\Rubik-Regular.ttf'),
#  ('Yet R', 'C:\\Windows\\Fonts\\HMFMOLD.TTF'),
#  ('Rockwell Condensed', 'C:\\Windows\\Fonts\\ROCC____.TTF'),
#  ('Calibri', 'C:\\Windows\\Fonts\\calibriz.ttf'),
#  ('Lucida Handwriting', 'C:\\Windows\\Fonts\\LHANDW.TTF'),
#  ('Segoe UI', 'C:\\Windows\\Fonts\\seguibl.ttf'),
#  ('Segoe UI Black', 'C:\\Windows\\Fonts\\seguibl.ttf'),
#  ('Yu Gothic', 'C:\\Windows\\Fonts\\YuGothM.ttc'),
#  ('Yu Gothic Medium', 'C:\\Windows\\Fonts\\YuGothM.ttc'),
#  ('Yu Gothic UI', 'C:\\Windows\\Fonts\\YuGothM.ttc'),
#  ('Noto Sans Lao', 'C:\\Windows\\Fonts\\NotoSansLao-Regular.ttf'),
#  ('Carlito', 'C:\\Windows\\Fonts\\Carlito-Regular.ttf'),
#  ('Miriam Mono CLM', 'C:\\Windows\\Fonts\\MiriamMonoCLM-BoldOblique.ttf'),
#  ('Franklin Gothic Book', 'C:\\Windows\\Fonts\\FRABK.TTF'),
#  ('Kristen ITC', 'C:\\Windows\\Fonts\\ITCKRIST.TTF'),
#  ('Wingdings 3', 'C:\\Windows\\Fonts\\WINGDNG3.TTF'),
#  ('Corbel', 'C:\\Windows\\Fonts\\corbelz.ttf'),
#  ('Franklin Gothic Demi', 'C:\\Windows\\Fonts\\FRADM.TTF'),
#  ('Liberation Mono', 'C:\\Windows\\Fonts\\LiberationMono-Italic.ttf'),
#  ('Miriam Libre', 'C:\\Windows\\Fonts\\MiriamLibre-Bold.otf'),
#  ('Microsoft Yi Baiti', 'C:\\Windows\\Fonts\\msyi.ttf'),
#  ('DejaVu Sans', 'C:\\Windows\\Fonts\\DejaVuSansCondensed-Bold.ttf'),
#  ('DejaVu Sans Condensed', 'C:\\Windows\\Fonts\\DejaVuSansCondensed-Bold.ttf'),
#  ('Book Antiqua', 'C:\\Windows\\Fonts\\ANTQUABI.TTF'),
#  ('Mongolian Baiti', 'C:\\Windows\\Fonts\\monbaiti.ttf'),
#  ('Courier New', 'C:\\Windows\\Fonts\\couri.ttf'),
#  ('Noto Sans', 'C:\\Windows\\Fonts\\NotoSans-Condensed.ttf'),
#  ('Noto Sans Cond', 'C:\\Windows\\Fonts\\NotoSans-Condensed.ttf'),
#  ('Microsoft YaHei', 'C:\\Windows\\Fonts\\msyh.ttc'),
#  ('Microsoft YaHei UI', 'C:\\Windows\\Fonts\\msyh.ttc'),
#  ('Wide Latin', 'C:\\Windows\\Fonts\\LATINWD.TTF'),
#  ('Bodoni MT', 'C:\\Windows\\Fonts\\BOD_CR.TTF'),
#  ('Bodoni MT Condensed', 'C:\\Windows\\Fonts\\BOD_CR.TTF'),
#  ('Times New Roman', 'C:\\Windows\\Fonts\\times.ttf'),
#  ('Californian FB', 'C:\\Windows\\Fonts\\CALIFR.TTF'),
#  ('Lucida Sans Unicode', 'C:\\Windows\\Fonts\\l_10646.ttf'),
#  ('Viner Hand ITC', 'C:\\Windows\\Fonts\\VINERITC.TTF'),
#  ('Noto Serif Armenian', 'C:\\Windows\\Fonts\\NotoSerifArmenian-Bold.ttf'),
#  ('Tw Cen MT', 'C:\\Windows\\Fonts\\TCMI____.TTF'),
#  ('Constantia', 'C:\\Windows\\Fonts\\constani.ttf'),
#  ('Segoe Print', 'C:\\Windows\\Fonts\\segoeprb.ttf'),
#  ('Cambria', 'C:\\Windows\\Fonts\\cambria.ttc'),
#  ('Cambria Math', 'C:\\Windows\\Fonts\\cambria.ttc'),
#  ('Corbel', 'C:\\Windows\\Fonts\\corbel.ttf'),
#  ('Century Gothic', 'C:\\Windows\\Fonts\\GOTHIC.TTF'),
#  ('Noto Sans KR',
#   'C:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Roaming\\YbmNet\\NotoSansKR-Bold.ttf'),
#  ('Impact', 'C:\\Windows\\Fonts\\impact.ttf'),
#  ('Calibri', 'C:\\Windows\\Fonts\\calibril.ttf'),
#  ('Calibri Light', 'C:\\Windows\\Fonts\\calibril.ttf'),
#  ('Dubai', 'C:\\Windows\\Fonts\\DUBAI-MEDIUM.TTF'),
#  ('Dubai Medium', 'C:\\Windows\\Fonts\\DUBAI-MEDIUM.TTF'),
#  ('Constantia', 'C:\\Windows\\Fonts\\constanb.ttf'),
#  ('Scheherazade', 'C:\\Windows\\Fonts\\Scheherazade-Regular.ttf'),
#  ('Frank Ruehl CLM', 'C:\\Windows\\Fonts\\FrankRuehlCLM-Medium.ttf'),
#  ('Arial', 'C:\\Windows\\Fonts\\ARIALNI.TTF'),
#  ('Arial Narrow', 'C:\\Windows\\Fonts\\ARIALNI.TTF'),
#  ('Playbill', 'C:\\Windows\\Fonts\\PLAYBILL.TTF'),
#  ('Linux Biolinum G', 'C:\\Windows\\Fonts\\LinBiolinum_R_G.ttf'),
#  ('Bodoni MT', 'C:\\Windows\\Fonts\\BOD_R.TTF'),
#  ('Noto Serif Armenian', 'C:\\Windows\\Fonts\\NotoSerifArmenian-Regular.ttf'),
#  ('Carlito', 'C:\\Windows\\Fonts\\Carlito-Italic.ttf'),
#  ('Centaur', 'C:\\Windows\\Fonts\\CENTAUR.TTF'),
#  ('Georgia', 'C:\\Windows\\Fonts\\georgiai.ttf'),
#  ('Liberation Serif', 'C:\\Windows\\Fonts\\LiberationSerif-Bold.ttf'),
#  ('Noto Sans Armenian', 'C:\\Windows\\Fonts\\NotoSansArmenian-Bold.ttf'),
#  ('Calibri', 'C:\\Windows\\Fonts\\calibrili.ttf'),
#  ('Calibri Light', 'C:\\Windows\\Fonts\\calibrili.ttf'),
#  ('Comic Sans MS', 'C:\\Windows\\Fonts\\comicz.ttf'),
#  ('HCR Batang ExtB', 'C:\\Windows\\Fonts\\HANBatangExtB.ttf'),
#  ('Perpetua', 'C:\\Windows\\Fonts\\PERBI___.TTF'),
#  ('Magic R', 'C:\\Windows\\Fonts\\HMKMMAG.TTF'),
#  ('Linux Libertine G', 'C:\\Windows\\Fonts\\LinLibertine_RZI_G.ttf'),
#  ('Han Santteut Dotum', 'C:\\Windows\\Fonts\\HanSantteutDotum-Bold.ttf'),
#  ('HYPost-Light', 'C:\\Windows\\Fonts\\H2PORL.TTF'),
#  ('Comic Sans MS', 'C:\\Windows\\Fonts\\comic.ttf'),
#  ('Tempus Sans ITC', 'C:\\Windows\\Fonts\\TEMPSITC.TTF'),
#  ('Noto Sans', 'C:\\Windows\\Fonts\\NotoSans-CondensedBoldItalic.ttf'),
#  ('Noto Sans Cond', 'C:\\Windows\\Fonts\\NotoSans-CondensedBoldItalic.ttf'),
#  ('Cascadia Mono', 'C:\\Windows\\Fonts\\CascadiaMono.ttf'),
#  ('Lucida Bright', 'C:\\Windows\\Fonts\\LBRITEI.TTF'),
#  ('Segoe UI', 'C:\\Windows\\Fonts\\segoeui.ttf'),
#  ('Constantia', 'C:\\Windows\\Fonts\\constanz.ttf'),
#  ('HCR Dotum', 'C:\\Windows\\Fonts\\HANDotumB.ttf'),
#  ('Segoe UI Emoji', 'C:\\Windows\\Fonts\\seguiemj.ttf'),
#  ('Lucida Sans', 'C:\\Windows\\Fonts\\LSANSI.TTF'),
#  ('Jokerman', 'C:\\Windows\\Fonts\\JOKERMAN.TTF'),
#  ('Linux Libertine G', 'C:\\Windows\\Fonts\\LinLibertine_RI_G.ttf'),
#  ('Wingdings', 'C:\\Windows\\Fonts\\wingding.ttf'),
#  ('HCR Dotum', 'C:\\Windows\\Fonts\\HANDotum.ttf'),
#  ('DejaVu Sans', 'C:\\Windows\\Fonts\\DejaVuSans-Bold.ttf'),
#  ('Segoe UI Variable', 'C:\\Windows\\Fonts\\SegUIVar.ttf'),
#  ('Liberation Sans Narrow',
#   'C:\\Windows\\Fonts\\LiberationSansNarrow-Regular.ttf'),
#  ('Berlin Sans FB', 'C:\\Windows\\Fonts\\BRLNSR.TTF'),
#  ('Bell MT', 'C:\\Windows\\Fonts\\BELLI.TTF'),
#  ('Sitka', 'C:\\Windows\\Fonts\\SitkaVF.ttf'),
#  ('Sitka Text', 'C:\\Windows\\Fonts\\SitkaVF.ttf'),
#  ('Bookman Old Style', 'C:\\Windows\\Fonts\\BOOKOS.TTF'),
#  ('Georgia', 'C:\\Windows\\Fonts\\georgiaz.ttf'),
#  ('Microsoft PhagsPa', 'C:\\Windows\\Fonts\\phagspa.ttf'),
#  ('Consolas', 'C:\\Windows\\Fonts\\consola.ttf'),
#  ('Kunstler Script', 'C:\\Windows\\Fonts\\KUNSTLER.TTF'),
#  ('Segoe UI Historic', 'C:\\Windows\\Fonts\\seguihis.ttf'),
#  ('Franklin Gothic Medium', 'C:\\Windows\\Fonts\\framd.ttf'),
#  ('HYPMokGak-Bold', 'C:\\Windows\\Fonts\\H2MKPB.TTF'),
#  ('Headline R', 'C:\\Windows\\Fonts\\HMKMRHD.TTF'),
#  ('Leelawadee UI', 'C:\\Windows\\Fonts\\LeelaUIb.ttf'),
#  ('Book Antiqua', 'C:\\Windows\\Fonts\\BKANT.TTF'),
#  ('DejaVu Sans Mono', 'C:\\Windows\\Fonts\\DejaVuSansMono-BoldOblique.ttf'),
#  ('Noto Serif Lao', 'C:\\Windows\\Fonts\\NotoSerifLao-Bold.ttf'),
#  ('Tw Cen MT', 'C:\\Windows\\Fonts\\TCB_____.TTF'),
#  ('HancomEQN', 'C:\\Windows\\Fonts\\HancomEQN.ttf'),
#  ('Lucida Fax', 'C:\\Windows\\Fonts\\LFAXDI.TTF'),
#  ('Bodoni MT', 'C:\\Windows\\Fonts\\BOD_CBI.TTF'),
#  ('Bodoni MT Condensed', 'C:\\Windows\\Fonts\\BOD_CBI.TTF'),
#  ('Miriam Mono CLM', 'C:\\Windows\\Fonts\\MiriamMonoCLM-Book.ttf'),
#  ('Garamond', 'C:\\Windows\\Fonts\\GARAIT.TTF'),
#  ('Alef', 'C:\\Windows\\Fonts\\Alef-Bold.ttf'),
#  ('Agency FB', 'C:\\Windows\\Fonts\\AGENCYR.TTF'),
#  ('Microsoft Sans Serif', 'C:\\Windows\\Fonts\\micross.ttf'),
#  ('Lucida Bright', 'C:\\Windows\\Fonts\\LBRITE.TTF'),
#  ('MS Reference Specialty', 'C:\\Windows\\Fonts\\REFSPCL.TTF'),
#  ('Calibri', 'C:\\Windows\\Fonts\\calibrib.ttf'),
#  ('CookieRun',
#   'C:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Microsoft\\Windows\\Fonts\\CookieRun Black.ttf'),
#  ('CookieRun Black',
#   'C:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Microsoft\\Windows\\Fonts\\CookieRun Black.ttf'),
#  ('Forte', 'C:\\Windows\\Fonts\\FORTE.TTF'),
#  ('Liberation Sans Narrow',
#   'C:\\Windows\\Fonts\\LiberationSansNarrow-Bold.ttf'),
#  ('DejaVu Serif', 'C:\\Windows\\Fonts\\DejaVuSerifCondensed-Bold.ttf'),
#  ('DejaVu Serif Condensed',
#   'C:\\Windows\\Fonts\\DejaVuSerifCondensed-Bold.ttf'),
#  ('Niagara Engraved', 'C:\\Windows\\Fonts\\NIAGENG.TTF'),
#  ('Bell MT', 'C:\\Windows\\Fonts\\BELLB.TTF'),
#  ('Noto Serif', 'C:\\Windows\\Fonts\\NotoSerif-LightItalic.ttf'),
#  ('Noto Serif Light', 'C:\\Windows\\Fonts\\NotoSerif-LightItalic.ttf'),
#  ('CookieRun',
#   'C:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Microsoft\\Windows\\Fonts\\CookieRun Bold.ttf'),
#  ('CookieRun Bold',
#   'C:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Microsoft\\Windows\\Fonts\\CookieRun Bold.ttf'),
#  ('Century Schoolbook', 'C:\\Windows\\Fonts\\SCHLBKI.TTF'),
#  ('Trebuchet MS', 'C:\\Windows\\Fonts\\trebucbi.ttf'),
#  ('Onyx', 'C:\\Windows\\Fonts\\ONYX.TTF'),
#  ('Gloucester MT Extra Condensed', 'C:\\Windows\\Fonts\\GLECB.TTF'),
#  ('Lucida Sans', 'C:\\Windows\\Fonts\\LSANSD.TTF'),
#  ('SimSun-ExtG', 'C:\\Windows\\Fonts\\SimsunExtG.ttf'),
#  ('CookieRun',
#   'C:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Microsoft\\Windows\\Fonts\\CookieRun Regular.ttf'),
#  ('CookieRun Regular',
#   'C:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Microsoft\\Windows\\Fonts\\CookieRun Regular.ttf'),
#  ('MT Extra', 'C:\\Windows\\Fonts\\MTEXTRA.TTF'),
#  ('Tahoma', 'C:\\Windows\\Fonts\\tahomabd.ttf'),
#  ('Trebuchet MS', 'C:\\Windows\\Fonts\\trebuc.ttf'),
#  ('Frank Ruehl CLM', 'C:\\Windows\\Fonts\\FrankRuehlCLM-BoldOblique.ttf'),
#  ('HCR Batang Ext', 'C:\\Windows\\Fonts\\HANBatangExt.ttf'),
#  ('Noto Serif Lao', 'C:\\Windows\\Fonts\\NotoSerifLao-Regular.ttf'),
#  ('Verdana', 'C:\\Windows\\Fonts\\verdanab.ttf'),
#  ('Perpetua', 'C:\\Windows\\Fonts\\PERI____.TTF'),
#  ('Nachlieli CLM', 'C:\\Windows\\Fonts\\NachlieliCLM-Bold.otf'),
#  ('DejaVu Sans', 'C:\\Windows\\Fonts\\DejaVuSansCondensed-BoldOblique.ttf'),
#  ('DejaVu Sans Condensed',
#   'C:\\Windows\\Fonts\\DejaVuSansCondensed-BoldOblique.ttf'),
#  ('Algerian', 'C:\\Windows\\Fonts\\ALGER.TTF'),
#  ('Lucida Sans', 'C:\\Windows\\Fonts\\LSANSDI.TTF'),
#  ('DejaVu Sans', 'C:\\Windows\\Fonts\\DejaVuSans.ttf'),
#  ('Corbel', 'C:\\Windows\\Fonts\\corbelli.ttf'),
#  ('Corbel Light', 'C:\\Windows\\Fonts\\corbelli.ttf'),
#  ('Verdana', 'C:\\Windows\\Fonts\\verdanaz.ttf'),
#  ('Caladea', 'C:\\Windows\\Fonts\\Caladea-BoldItalic.ttf'),
#  ('Noto Sans', 'C:\\Windows\\Fonts\\NotoSans-CondensedBold.ttf'),
#  ('Noto Sans Cond', 'C:\\Windows\\Fonts\\NotoSans-CondensedBold.ttf'),
#  ('Miriam CLM', 'C:\\Windows\\Fonts\\MiriamCLM-Bold.ttf'),
#  ('Modern No. 20', 'C:\\Windows\\Fonts\\MOD20.TTF'),
#  ('Liberation Sans', 'C:\\Windows\\Fonts\\LiberationSans-Regular.ttf'),
#  ('Dubai', 'C:\\Windows\\Fonts\\DUBAI-LIGHT.TTF'),
#  ('Dubai Light', 'C:\\Windows\\Fonts\\DUBAI-LIGHT.TTF'),
#  ('Castellar', 'C:\\Windows\\Fonts\\CASTELAR.TTF'),
#  ('Calibri', 'C:\\Windows\\Fonts\\calibri.ttf'),
#  ('Gill Sans MT', 'C:\\Windows\\Fonts\\GIL_____.TTF'),
#  ('Cooper Black', 'C:\\Windows\\Fonts\\COOPBL.TTF'),
#  ('Footlight MT Light', 'C:\\Windows\\Fonts\\FTLTLT.TTF'),
#  ('Myanmar Text', 'C:\\Windows\\Fonts\\mmrtextb.ttf'),
#  ('Calisto MT', 'C:\\Windows\\Fonts\\CALISTBI.TTF'),
#  ('Segoe Fluent Icons', 'C:\\Windows\\Fonts\\SegoeIcons.ttf'),
#  ('Gadugi', 'C:\\Windows\\Fonts\\gadugi.ttf'),
#  ('Noto Sans', 'C:\\Windows\\Fonts\\NotoSans-Bold.ttf'),
#  ('Edwardian Script ITC', 'C:\\Windows\\Fonts\\ITCEDSCR.TTF'),
#  ('HYGungSo-Bold', 'C:\\Windows\\Fonts\\H2GSRB.TTF'),
#  ('Niagara Solid', 'C:\\Windows\\Fonts\\NIAGSOL.TTF'),
#  ('Colonna MT', 'C:\\Windows\\Fonts\\COLONNA.TTF'),
#  ('DejaVu Math TeX Gyre', 'C:\\Windows\\Fonts\\DejaVuMathTeXGyre.ttf'),
#  ('Bell MT', 'C:\\Windows\\Fonts\\BELL.TTF'),
#  ('Amiri', 'C:\\Windows\\Fonts\\Amiri-Bold.ttf'),
#  ('Carlito', 'C:\\Windows\\Fonts\\Carlito-BoldItalic.ttf'),
#  ('Arial', 'C:\\Windows\\Fonts\\ARIALN.TTF'),
#  ('Arial Narrow', 'C:\\Windows\\Fonts\\ARIALN.TTF'),
#  ('HCR Batang ExtB', 'C:\\Windows\\Fonts\\HANBatangExtBB.ttf'),
#  ('Lucida Sans', 'C:\\Windows\\Fonts\\LSANS.TTF'),
#  ('Gabriola', 'C:\\Windows\\Fonts\\Gabriola.ttf'),
#  ('Times New Roman', 'C:\\Windows\\Fonts\\timesbi.ttf'),
#  ('Tw Cen MT', 'C:\\Windows\\Fonts\\TCBI____.TTF'),
#  ('MS Reference Sans Serif', 'C:\\Windows\\Fonts\\REFSAN.TTF'),
#  ('Century Gothic', 'C:\\Windows\\Fonts\\GOTHICB.TTF'),
#  ('Miriam Libre', 'C:\\Windows\\Fonts\\MiriamLibre-Regular.otf'),
#  ('Rockwell', 'C:\\Windows\\Fonts\\ROCKBI.TTF'),
#  ('Chiller', 'C:\\Windows\\Fonts\\CHILLER.TTF'),
#  ('Bodoni MT', 'C:\\Windows\\Fonts\\BOD_PSTC.TTF'),
#  ('Bodoni MT Poster Compressed', 'C:\\Windows\\Fonts\\BOD_PSTC.TTF'),
#  ('Noto Serif KR', 'C:\\Windows\\Fonts\\NotoSerifKR-VF.ttf'),
#  ('Noto Sans Georgian', 'C:\\Windows\\Fonts\\NotoSansGeorgian-Regular.ttf'),
#  ('Noto Sans Arabic UI', 'C:\\Windows\\Fonts\\NotoSansArabicUI-Regular.ttf'),
#  ('Linux Biolinum G', 'C:\\Windows\\Fonts\\LinBiolinum_RI_G.ttf'),
#  ('Lucida Fax', 'C:\\Windows\\Fonts\\LFAXI.TTF'),
#  ('Leelawadee UI', 'C:\\Windows\\Fonts\\LeelUIsl.ttf'),
#  ('Leelawadee UI Semilight', 'C:\\Windows\\Fonts\\LeelUIsl.ttf'),
#  ('Bookshelf Symbol 7', 'C:\\Windows\\Fonts\\BSSYM7.TTF'),
#  ('Noto Serif', 'C:\\Windows\\Fonts\\NotoSerif-Regular.ttf'),
#  ('DejaVu Sans', 'C:\\Windows\\Fonts\\DejaVuSans-BoldOblique.ttf'),
#  ('Wingdings 2', 'C:\\Windows\\Fonts\\WINGDNG2.TTF'),
#  ('Microsoft JhengHei', 'C:\\Windows\\Fonts\\msjh.ttc'),
#  ('Microsoft JhengHei UI', 'C:\\Windows\\Fonts\\msjh.ttc'),
#  ('Noto Serif', 'C:\\Windows\\Fonts\\NotoSerif-BoldItalic.ttf'),
#  ('Snap ITC', 'C:\\Windows\\Fonts\\SNAP____.TTF'),
#  ('Rockwell', 'C:\\Windows\\Fonts\\ROCKB.TTF'),
#  ('Cascadia Code', 'C:\\Windows\\Fonts\\CascadiaCode.ttf'),
#  ('Times New Roman', 'C:\\Windows\\Fonts\\timesbd.ttf'),
#  ('DejaVu Serif', 'C:\\Windows\\Fonts\\DejaVuSerifCondensed-Italic.ttf'),
#  ('DejaVu Serif Condensed',
#   'C:\\Windows\\Fonts\\DejaVuSerifCondensed-Italic.ttf'),
#  ('David CLM', 'C:\\Windows\\Fonts\\DavidCLM-MediumItalic.otf'),
#  ('HYGraphic-Medium', 'C:\\Windows\\Fonts\\H2GPRM.TTF'),
#  ('Microsoft JhengHei', 'C:\\Windows\\Fonts\\msjhl.ttc'),
#  ('Microsoft JhengHei Light', 'C:\\Windows\\Fonts\\msjhl.ttc'),
#  ('Microsoft JhengHei UI', 'C:\\Windows\\Fonts\\msjhl.ttc'),
#  ('Microsoft JhengHei UI Light', 'C:\\Windows\\Fonts\\msjhl.ttc'),
#  ('Elephant', 'C:\\Windows\\Fonts\\ELEPHNTI.TTF'),
#  ('Goudy Old Style', 'C:\\Windows\\Fonts\\GOUDOSB.TTF'),
#  ('Microsoft PhagsPa', 'C:\\Windows\\Fonts\\phagspab.ttf'),
#  ('Noto Sans', 'C:\\Windows\\Fonts\\NotoSans-Regular.ttf'),
#  ('High Tower Text', 'C:\\Windows\\Fonts\\HTOWERT.TTF'),
#  ('netmarble',
#   'C:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Microsoft\\Windows\\Fonts\\netmarbleB.ttf'),
#  ('netmarble Bold',
#   'C:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Microsoft\\Windows\\Fonts\\netmarbleB.ttf'),
#  ('Candara', 'C:\\Windows\\Fonts\\Candara.ttf'),
#  ('Candara', 'C:\\Windows\\Fonts\\Candaraz.ttf'),
#  ('DejaVu Serif', 'C:\\Windows\\Fonts\\DejaVuSerifCondensed-BoldItalic.ttf'),
#  ('DejaVu Serif Condensed',
#   'C:\\Windows\\Fonts\\DejaVuSerifCondensed-BoldItalic.ttf'),
#  ('Showcard Gothic', 'C:\\Windows\\Fonts\\SHOWG.TTF'),
#  ('Liberation Sans', 'C:\\Windows\\Fonts\\LiberationSans-Italic.ttf'),
#  ('Malgun Gothic', 'C:\\Windows\\Fonts\\malgunsl.ttf'),
#  ('Malgun Gothic Semilight', 'C:\\Windows\\Fonts\\malgunsl.ttf'),
#  ('Microsoft Tai Le', 'C:\\Windows\\Fonts\\taileb.ttf'),
#  ('Segoe UI', 'C:\\Windows\\Fonts\\seguisbi.ttf'),
#  ('Segoe UI Semibold', 'C:\\Windows\\Fonts\\seguisbi.ttf'),
#  ('Malgun Gothic', 'C:\\Windows\\Fonts\\malgunbd.ttf'),
#  ('Reem Kufi', 'C:\\Windows\\Fonts\\ReemKufi-Bold.ttf'),
#  ('DejaVu Sans Mono', 'C:\\Windows\\Fonts\\DejaVuSansMono-Bold.ttf'),
#  ('Century Gothic', 'C:\\Windows\\Fonts\\GOTHICBI.TTF'),
#  ('Bookman Old Style', 'C:\\Windows\\Fonts\\BOOKOSBI.TTF'),
#  ('Gentium Basic', 'C:\\Windows\\Fonts\\GenBasI.ttf'),
#  ('HCR Dotum Ext', 'C:\\Windows\\Fonts\\HANDotumExt.ttf'),
#  ('netmarble',
#   'C:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Microsoft\\Windows\\Fonts\\netmarbleM.ttf'),
#  ('netmarble Medium',
#   'C:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Microsoft\\Windows\\Fonts\\netmarbleM.ttf'),
#  ('Carlito', 'C:\\Windows\\Fonts\\Carlito-Bold.ttf'),
#  ('Reem Kufi', 'C:\\Windows\\Fonts\\ReemKufi-Regular.ttf'),
#  ('Vladimir Script', 'C:\\Windows\\Fonts\\VLADIMIR.TTF'),
#  ('Hancom Hoonminjeongeum_H',
#   'C:\\Windows\\Fonts\\HancomHoonminjeongeumH.ttf'),
#  ('Century', 'C:\\Windows\\Fonts\\CENTURY.TTF'),
#  ('Bauhaus 93', 'C:\\Windows\\Fonts\\BAUHS93.TTF'),
#  ('Corbel', 'C:\\Windows\\Fonts\\corbell.ttf'),
#  ('Corbel Light', 'C:\\Windows\\Fonts\\corbell.ttf'),
#  ('Microsoft New Tai Lue', 'C:\\Windows\\Fonts\\ntailub.ttf'),
#  ('Noto Naskh Arabic UI', 'C:\\Windows\\Fonts\\NotoNaskhArabicUI-Regular.ttf'),
#  ('Segoe UI', 'C:\\Windows\\Fonts\\seguili.ttf'),
#  ('Segoe UI Light', 'C:\\Windows\\Fonts\\seguili.ttf'),
#  ('Broadway', 'C:\\Windows\\Fonts\\BROADW.TTF'),
#  ('Gill Sans MT', 'C:\\Windows\\Fonts\\GILI____.TTF'),
#  ('Parchment', 'C:\\Windows\\Fonts\\PARCHM.TTF'),
#  ('Bodoni MT', 'C:\\Windows\\Fonts\\BOD_BLAI.TTF'),
#  ('Bodoni MT Black', 'C:\\Windows\\Fonts\\BOD_BLAI.TTF'),
#  ('Gentium Book Basic', 'C:\\Windows\\Fonts\\GenBkBasBI.ttf'),
#  ('DejaVu Sans Mono', 'C:\\Windows\\Fonts\\DejaVuSansMono.ttf'),
#  ('Liberation Sans Narrow',
#   'C:\\Windows\\Fonts\\LiberationSansNarrow-BoldItalic.ttf'),
#  ('David CLM', 'C:\\Windows\\Fonts\\DavidCLM-Bold.otf'),
#  ('Book Antiqua', 'C:\\Windows\\Fonts\\ANTQUAB.TTF'),
#  ('Magneto', 'C:\\Windows\\Fonts\\MAGNETOB.TTF'),
#  ('Copperplate Gothic Bold', 'C:\\Windows\\Fonts\\COPRGTB.TTF'),
#  ('Noto Sans Arabic', 'C:\\Windows\\Fonts\\NotoSansArabic-Regular.ttf'),
#  ('Hancom Gothic', 'C:\\Windows\\Fonts\\Hancom Gothic Bold.ttf'),
#  ('Noto Sans Hebrew', 'C:\\Windows\\Fonts\\NotoSansHebrew-Regular.ttf'),
#  ('Courier New', 'C:\\Windows\\Fonts\\cour.ttf'),
#  ('Noto Kufi Arabic', 'C:\\Windows\\Fonts\\NotoKufiArabic-Bold.ttf'),
#  ('Calibri', 'C:\\Windows\\Fonts\\calibrii.ttf'),
#  ('Noto Serif', 'C:\\Windows\\Fonts\\NotoSerif-Italic.ttf'),
#  ('Ebrima', 'C:\\Windows\\Fonts\\ebrimabd.ttf'),
#  ('Rage Italic', 'C:\\Windows\\Fonts\\RAGE.TTF'),
#  ('MS Gothic', 'C:\\Windows\\Fonts\\msgothic.ttc'),
#  ('MS UI Gothic', 'C:\\Windows\\Fonts\\msgothic.ttc'),
#  ('MS PGothic', 'C:\\Windows\\Fonts\\msgothic.ttc'),
#  ('Rubik', 'C:\\Windows\\Fonts\\Rubik-Bold.ttf'),
#  ('Blackadder ITC', 'C:\\Windows\\Fonts\\ITCBLKAD.TTF'),
#  ('Rockwell Condensed', 'C:\\Windows\\Fonts\\ROCCB___.TTF'),
#  ('Candara', 'C:\\Windows\\Fonts\\Candaral.ttf'),
#  ('Candara Light', 'C:\\Windows\\Fonts\\Candaral.ttf'),
#  ('Imprint MT Shadow', 'C:\\Windows\\Fonts\\IMPRISHA.TTF'),
#  ('David CLM', 'C:\\Windows\\Fonts\\DavidCLM-BoldItalic.otf'),
#  ('Segoe Script', 'C:\\Windows\\Fonts\\segoescb.ttf'),
#  ('Bookman Old Style', 'C:\\Windows\\Fonts\\BOOKOSB.TTF'),
#  ('Gill Sans Ultra Bold', 'C:\\Windows\\Fonts\\GILSANUB.TTF'),
#  ('Bahnschrift', 'C:\\Windows\\Fonts\\bahnschrift.ttf'),
#  ('Segoe Print', 'C:\\Windows\\Fonts\\segoepr.ttf'),
#  ('Arial', 'C:\\Windows\\Fonts\\arialbi.ttf'),
#  ('Lucida Calligraphy', 'C:\\Windows\\Fonts\\LCALLIG.TTF'),
#  ('Yu Gothic', 'C:\\Windows\\Fonts\\YuGothL.ttc'),
#  ('Yu Gothic Light', 'C:\\Windows\\Fonts\\YuGothL.ttc'),
#  ('Yu Gothic UI', 'C:\\Windows\\Fonts\\YuGothL.ttc'),
#  ('Yu Gothic UI Light', 'C:\\Windows\\Fonts\\YuGothL.ttc'),
#  ('Hancom MalangMalang', 'C:\\Windows\\Fonts\\MalangmalangB.ttf'),
#  ('Hancom MalangMalang Bold', 'C:\\Windows\\Fonts\\MalangmalangB.ttf'),
#  ('Lucida Console', 'C:\\Windows\\Fonts\\lucon.ttf'),
#  ('NewJumja', 'C:\\Windows\\Fonts\\JUMJA.TTF'),
#  ('Noto Sans Arabic UI', 'C:\\Windows\\Fonts\\NotoSansArabicUI-Bold.ttf'),
#  ('Noto Sans Lisu', 'C:\\Windows\\Fonts\\NotoSansLisu-Regular.ttf'),
#  ('Segoe MDL2 Assets', 'C:\\Windows\\Fonts\\segmdl2.ttf'),
#  ('Segoe UI', 'C:\\Windows\\Fonts\\seguibli.ttf'),
#  ('Segoe UI Black', 'C:\\Windows\\Fonts\\seguibli.ttf'),
#  ('Palatino Linotype', 'C:\\Windows\\Fonts\\palab.ttf'),
#  ('Consolas', 'C:\\Windows\\Fonts\\consolai.ttf'),
#  ('Franklin Gothic Demi', 'C:\\Windows\\Fonts\\FRADMIT.TTF'),
#  ('Baskerville Old Face', 'C:\\Windows\\Fonts\\BASKVILL.TTF'),
#  ('Times New Roman', 'C:\\Windows\\Fonts\\timesi.ttf'),
#  ('Perpetua', 'C:\\Windows\\Fonts\\PER_____.TTF'),
#  ('HYPost-Medium', 'C:\\Windows\\Fonts\\H2PORM.TTF'),
#  ('Ami R', 'C:\\Windows\\Fonts\\HMKMAMI.TTF'),
#  ('Lucida Sans Typewriter', 'C:\\Windows\\Fonts\\LTYPEO.TTF'),
#  ('Brush Script MT', 'C:\\Windows\\Fonts\\BRUSHSCI.TTF'),
#  ('Californian FB', 'C:\\Windows\\Fonts\\CALIFB.TTF'),
#  ('Verdana', 'C:\\Windows\\Fonts\\verdana.ttf'),
#  ('Maiandra GD', 'C:\\Windows\\Fonts\\MAIAN.TTF'),
#  ('Noto Sans KR', 'C:\\Windows\\Fonts\\NotoSansKR-VF.ttf'),
#  ('Ravie', 'C:\\Windows\\Fonts\\RAVIE.TTF'),
#  ('Frank Ruhl Hofshi', 'C:\\Windows\\Fonts\\FrankRuhlHofshi-Regular.otf'),
#  ('Rockwell', 'C:\\Windows\\Fonts\\ROCKI.TTF'),
#  ('French Script MT', 'C:\\Windows\\Fonts\\FRSCRIPT.TTF'),
#  ('Noto Naskh Arabic UI', 'C:\\Windows\\Fonts\\NotoNaskhArabicUI-Bold.ttf'),
#  ('HYShortSamul-Medium', 'C:\\Windows\\Fonts\\H2SA1M.TTF'),
#  ('netmarble',
#   'C:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Microsoft\\Windows\\Fonts\\netmarbleL.ttf'),
#  ('netmarble Light',
#   'C:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Microsoft\\Windows\\Fonts\\netmarbleL.ttf'),
#  ('DejaVu Sans Mono', 'C:\\Windows\\Fonts\\DejaVuSansMono-Oblique.ttf'),
#  ('OCR A Extended', 'C:\\Windows\\Fonts\\OCRAEXT.TTF'),
#  ('Calisto MT', 'C:\\Windows\\Fonts\\CALISTB.TTF'),
#  ('David Libre', 'C:\\Windows\\Fonts\\DavidLibre-Regular.ttf'),
#  ('David Libre', 'C:\\Windows\\Fonts\\DavidLibre-Bold.ttf'),
#  ('Mistral', 'C:\\Windows\\Fonts\\MISTRAL.TTF'),
#  ('Liberation Mono', 'C:\\Windows\\Fonts\\LiberationMono-BoldItalic.ttf'),
#  ('Alef', 'C:\\Windows\\Fonts\\Alef-Regular.ttf'),
#  ('Segoe UI Symbol', 'C:\\Windows\\Fonts\\seguisym.ttf'),
#  ('Dubai', 'C:\\Windows\\Fonts\\DUBAI-REGULAR.TTF'),
#  ('Liberation Sans', 'C:\\Windows\\Fonts\\LiberationSans-BoldItalic.ttf'),
#  ('Felix Titling', 'C:\\Windows\\Fonts\\FELIXTI.TTF'),
#  ('Book Antiqua', 'C:\\Windows\\Fonts\\ANTQUAI.TTF'),
#  ('Bookman Old Style', 'C:\\Windows\\Fonts\\BOOKOSI.TTF'),
#  ('MoeumT R', 'C:\\Windows\\Fonts\\HMFMMUEX.TTC'),
#  ('Expo M', 'C:\\Windows\\Fonts\\HMFMMUEX.TTC'),
#  ('Garamond', 'C:\\Windows\\Fonts\\GARA.TTF'),
#  ('Arial', 'C:\\Windows\\Fonts\\arialbd.ttf'),
#  ('Courier New', 'C:\\Windows\\Fonts\\courbi.ttf'),
#  ('Corbel', 'C:\\Windows\\Fonts\\corbeli.ttf'),
#  ('Miriam Mono CLM', 'C:\\Windows\\Fonts\\MiriamMonoCLM-Bold.ttf'),
#  ('Palatino Linotype', 'C:\\Windows\\Fonts\\palabi.ttf'),
#  ('Freestyle Script', 'C:\\Windows\\Fonts\\FREESCPT.TTF'),
#  ('Noto Mono', 'C:\\Windows\\Fonts\\NotoMono-Regular.ttf'),
#  ('Liberation Serif', 'C:\\Windows\\Fonts\\LiberationSerif-BoldItalic.ttf'),
#  ('Amiri', 'C:\\Windows\\Fonts\\Amiri-BoldItalic.ttf'),
#  ('Segoe UI', 'C:\\Windows\\Fonts\\segoeuisl.ttf'),
#  ('Segoe UI Semilight', 'C:\\Windows\\Fonts\\segoeuisl.ttf'),
#  ('Noto Serif', 'C:\\Windows\\Fonts\\NotoSerif-Condensed.ttf'),
#  ('Noto Serif Cond', 'C:\\Windows\\Fonts\\NotoSerif-Condensed.ttf'),
#  ('Old English Text MT', 'C:\\Windows\\Fonts\\OLDENGL.TTF'),
#  ('Linux Libertine G', 'C:\\Windows\\Fonts\\LinLibertine_RZ_G.ttf'),
#  ('Noto Serif Georgian', 'C:\\Windows\\Fonts\\NotoSerifGeorgian-Regular.ttf'),
#  ('Ebrima', 'C:\\Windows\\Fonts\\ebrima.ttf'),
#  ('Rockwell Extra Bold', 'C:\\Windows\\Fonts\\ROCKEB.TTF'),
#  ('Gentium Book Basic', 'C:\\Windows\\Fonts\\GenBkBasR.ttf'),
#  ('Maplestory',
#   'C:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Microsoft\\Windows\\Fonts\\Maplestory Bold.ttf'),
#  ('Tw Cen MT', 'C:\\Windows\\Fonts\\TCM_____.TTF'),
#  ('Amiri', 'C:\\Windows\\Fonts\\Amiri-Regular.ttf'),
#  ('Copperplate Gothic Light', 'C:\\Windows\\Fonts\\COPRGTL.TTF'),
#  ('Garamond', 'C:\\Windows\\Fonts\\GARABD.TTF'),
#  ('Palace Script MT', 'C:\\Windows\\Fonts\\PALSCRI.TTF'),
#  ('Linux Libertine G', 'C:\\Windows\\Fonts\\LinLibertine_RB_G.ttf'),
#  ('Verdana', 'C:\\Windows\\Fonts\\verdanai.ttf'),
#  ('Perpetua Titling MT', 'C:\\Windows\\Fonts\\PERTIBD.TTF'),
#  ('Agency FB', 'C:\\Windows\\Fonts\\AGENCYB.TTF'),
#  ('HYGothic-Medium', 'C:\\Windows\\Fonts\\H2GTRM.TTF'),
#  ('Noto Serif', 'C:\\Windows\\Fonts\\NotoSerif-CondensedBold.ttf'),
#  ('Noto Serif Cond', 'C:\\Windows\\Fonts\\NotoSerif-CondensedBold.ttf'),
#  ('Caladea', 'C:\\Windows\\Fonts\\Caladea-Italic.ttf'),
#  ('Georgia', 'C:\\Windows\\Fonts\\georgiab.ttf'),
#  ('Franklin Gothic Heavy', 'C:\\Windows\\Fonts\\FRAHVIT.TTF'),
#  ('Lucida Fax', 'C:\\Windows\\Fonts\\LFAXD.TTF'),
#  ('Segoe UI', 'C:\\Windows\\Fonts\\segoeuil.ttf'),
#  ('Segoe UI Light', 'C:\\Windows\\Fonts\\segoeuil.ttf'),
#  ('Noto Serif', 'C:\\Windows\\Fonts\\NotoSerif-Light.ttf'),
#  ('Noto Serif Light', 'C:\\Windows\\Fonts\\NotoSerif-Light.ttf'),
#  ('Comic Sans MS', 'C:\\Windows\\Fonts\\comicbd.ttf'),
#  ('Harrington', 'C:\\Windows\\Fonts\\HARNGTON.TTF'),
#  ('Noto Sans Hebrew', 'C:\\Windows\\Fonts\\NotoSansHebrew-Bold.ttf'),
#  ('Liberation Serif', 'C:\\Windows\\Fonts\\LiberationSerif-Regular.ttf'),
#  ('Linux Libertine G', 'C:\\Windows\\Fonts\\LinLibertine_RBI_G.ttf'),
#  ('Goudy Stout', 'C:\\Windows\\Fonts\\GOUDYSTO.TTF'),
#  ('Myanmar Text', 'C:\\Windows\\Fonts\\mmrtext.ttf'),
#  ('Linux Libertine Display G', 'C:\\Windows\\Fonts\\LinLibertine_DR_G.ttf'),
#  ('DejaVu Serif', 'C:\\Windows\\Fonts\\DejaVuSerif-Italic.ttf'),
#  ('Noto Sans', 'C:\\Windows\\Fonts\\NotoSans-BoldItalic.ttf'),
#  ('Lucida Bright', 'C:\\Windows\\Fonts\\LBRITED.TTF'),
#  ('DejaVu Sans', 'C:\\Windows\\Fonts\\DejaVuSansCondensed-Oblique.ttf'),
#  ('DejaVu Sans Condensed',
#   'C:\\Windows\\Fonts\\DejaVuSansCondensed-Oblique.ttf'),
#  ('Microsoft YaHei', 'C:\\Windows\\Fonts\\msyhl.ttc'),
#  ('Microsoft YaHei Light', 'C:\\Windows\\Fonts\\msyhl.ttc'),
#  ('Microsoft YaHei UI', 'C:\\Windows\\Fonts\\msyhl.ttc'),
#  ('Microsoft YaHei UI Light', 'C:\\Windows\\Fonts\\msyhl.ttc'),
#  ('Haettenschweiler', 'C:\\Windows\\Fonts\\HATTEN.TTF'),
#  ('Pristina', 'C:\\Windows\\Fonts\\PRISTINA.TTF'),
#  ('Berlin Sans FB Demi', 'C:\\Windows\\Fonts\\BRLNSDB.TTF'),
#  ('Amiri Quran', 'C:\\Windows\\Fonts\\AmiriQuran.ttf'),
#  ('Malgun Gothic', 'C:\\Windows\\Fonts\\malgun.ttf'),
#  ('Gill Sans MT Condensed', 'C:\\Windows\\Fonts\\GILC____.TTF'),
#  ('Noto Sans Georgian', 'C:\\Windows\\Fonts\\NotoSansGeorgian-Bold.ttf'),
#  ('Cambria', 'C:\\Windows\\Fonts\\cambriaz.ttf'),
#  ('DejaVu Serif', 'C:\\Windows\\Fonts\\DejaVuSerif.ttf'),
#  ('Miriam CLM', 'C:\\Windows\\Fonts\\MiriamCLM-Book.ttf'),
#  ('Linux Libertine G', 'C:\\Windows\\Fonts\\LinLibertine_R_G.ttf'),
#  ('Arial', 'C:\\Windows\\Fonts\\ARIALNB.TTF'),
#  ('Arial Narrow', 'C:\\Windows\\Fonts\\ARIALNB.TTF'),
#  ('DejaVu Serif', 'C:\\Windows\\Fonts\\DejaVuSerif-BoldItalic.ttf'),
#  ('Batang', 'C:\\Windows\\Fonts\\batang.ttc'),
#  ('BatangChe', 'C:\\Windows\\Fonts\\batang.ttc'),
#  ('Gungsuh', 'C:\\Windows\\Fonts\\batang.ttc'),
#  ('GungsuhChe', 'C:\\Windows\\Fonts\\batang.ttc'),
#  ('Dubai', 'C:\\Windows\\Fonts\\DUBAI-BOLD.TTF'),
#  ('Cambria', 'C:\\Windows\\Fonts\\cambriab.ttf'),
#  ('Calisto MT', 'C:\\Windows\\Fonts\\CALISTI.TTF'),
#  ('Rubik', 'C:\\Windows\\Fonts\\Rubik-BoldItalic.ttf'),
#  ('Sans Serif Collection', 'C:\\Windows\\Fonts\\SansSerifCollection.ttf'),
#  ('Liberation Serif', 'C:\\Windows\\Fonts\\LiberationSerif-Italic.ttf'),
#  ('Bodoni MT', 'C:\\Windows\\Fonts\\BOD_CI.TTF'),
#  ('Bodoni MT Condensed', 'C:\\Windows\\Fonts\\BOD_CI.TTF'),
#  ('Harlow Solid Italic', 'C:\\Windows\\Fonts\\HARLOWSI.TTF'),
#  ('High Tower Text', 'C:\\Windows\\Fonts\\HTOWERTI.TTF'),
#  ('Trebuchet MS', 'C:\\Windows\\Fonts\\trebucbd.ttf'),
#  ('Sylfaen', 'C:\\Windows\\Fonts\\sylfaen.ttf'),
#  ('Liberation Mono', 'C:\\Windows\\Fonts\\LiberationMono-Bold.ttf'),
#  ('Hancom MalangMalang', 'C:\\Windows\\Fonts\\MalangmalangR.ttf'),
#  ('Hancom MalangMalang Regular', 'C:\\Windows\\Fonts\\MalangmalangR.ttf'),
#  ('Gentium Basic', 'C:\\Windows\\Fonts\\GenBasB.ttf'),
#  ('Gill Sans Ultra Bold Condensed', 'C:\\Windows\\Fonts\\GILLUBCD.TTF'),
#  ('Lucida Bright', 'C:\\Windows\\Fonts\\LBRITEDI.TTF'),
#  ('Liberation Mono', 'C:\\Windows\\Fonts\\LiberationMono-Regular.ttf'),
#  ('Noto Naskh Arabic', 'C:\\Windows\\Fonts\\NotoNaskhArabic-Bold.ttf'),
#  ('DejaVu Sans', 'C:\\Windows\\Fonts\\DejaVuSans-ExtraLight.ttf'),
#  ('DejaVu Sans Light', 'C:\\Windows\\Fonts\\DejaVuSans-ExtraLight.ttf'),
#  ('Linux Biolinum G', 'C:\\Windows\\Fonts\\LinBiolinum_RB_G.ttf'),
#  ('MS Outlook', 'C:\\Windows\\Fonts\\OUTLOOK.TTF'),
#  ('Consolas', 'C:\\Windows\\Fonts\\consolab.ttf'),
#  ('Calisto MT', 'C:\\Windows\\Fonts\\CALIST.TTF'),
#  ('Stencil', 'C:\\Windows\\Fonts\\STENCIL.TTF'),
#  ('Britannic Bold', 'C:\\Windows\\Fonts\\BRITANIC.TTF'),
#  ('Century Schoolbook', 'C:\\Windows\\Fonts\\SCHLBKB.TTF'),
#  ('Century Gothic', 'C:\\Windows\\Fonts\\GOTHICI.TTF'),
#  ('Elephant', 'C:\\Windows\\Fonts\\ELEPHNT.TTF'),
#  ('Gentium Book Basic', 'C:\\Windows\\Fonts\\GenBkBasB.ttf'),
#  ('New Gulim', 'C:\\Windows\\Fonts\\NGULIM.TTF'),
#  ('Noto Serif Hebrew', 'C:\\Windows\\Fonts\\NotoSerifHebrew-Bold.ttf'),
#  ('Scheherazade', 'C:\\Windows\\Fonts\\Scheherazade-Bold.ttf'),
#  ('Bodoni MT', 'C:\\Windows\\Fonts\\BOD_I.TTF'),
#  ('Perpetua', 'C:\\Windows\\Fonts\\PERB____.TTF'),
#  ('Nachlieli CLM', 'C:\\Windows\\Fonts\\NachlieliCLM-LightOblique.otf'),
#  ('Noto Serif', 'C:\\Windows\\Fonts\\NotoSerif-CondensedItalic.ttf'),
#  ('Noto Serif Cond', 'C:\\Windows\\Fonts\\NotoSerif-CondensedItalic.ttf'),
#  ('Arial', 'C:\\Windows\\Fonts\\ariali.ttf'),
#  ('Microsoft JhengHei', 'C:\\Windows\\Fonts\\msjhbd.ttc'),
#  ('Microsoft JhengHei UI', 'C:\\Windows\\Fonts\\msjhbd.ttc'),
#  ('Ink Free', 'C:\\Windows\\Fonts\\Inkfree.ttf'),
#  ('Yu Gothic', 'C:\\Windows\\Fonts\\YuGothB.ttc'),
#  ('Yu Gothic UI', 'C:\\Windows\\Fonts\\YuGothB.ttc'),
#  ('Yu Gothic UI', 'C:\\Windows\\Fonts\\YuGothB.ttc'),
#  ('Yu Gothic UI Semibold', 'C:\\Windows\\Fonts\\YuGothB.ttc'),
#  ('Vivaldi', 'C:\\Windows\\Fonts\\VIVALDII.TTF'),
#  ('Rubik', 'C:\\Windows\\Fonts\\Rubik-Italic.ttf'),
#  ('Tw Cen MT Condensed', 'C:\\Windows\\Fonts\\TCCM____.TTF'),
#  ('Frank Ruehl CLM', 'C:\\Windows\\Fonts\\FrankRuehlCLM-MediumOblique.ttf'),
#  ('DejaVu Sans', 'C:\\Windows\\Fonts\\DejaVuSansCondensed.ttf'),
#  ('DejaVu Sans Condensed', 'C:\\Windows\\Fonts\\DejaVuSansCondensed.ttf'),
#  ('HYGothic-Extra', 'C:\\Windows\\Fonts\\H2GTRE.TTF'),
#  ('Franklin Gothic Heavy', 'C:\\Windows\\Fonts\\FRAHV.TTF'),
#  ('Corbel', 'C:\\Windows\\Fonts\\corbelb.ttf'),
#  ('Noto Sans Armenian', 'C:\\Windows\\Fonts\\NotoSansArmenian-Regular.ttf'),
#  ('Bradley Hand ITC', 'C:\\Windows\\Fonts\\BRADHITC.TTF'),
#  ('Maplestory',
#   'C:\\Users\\User.DESKTOP-G5S2APU\\AppData\\Local\\Microsoft\\Windows\\Fonts\\Maplestory Light.ttf')]

# %%
# font name을 알고 있다면 생략가능
#한글폰트 path 설정
font_path = 'C:\\Windows\\Fonts\\malgun.ttf'
#font의 파일정보로 font name 을 알아내기
font_name = fm.FontProperties(fname=font_path).get_name()
print(font_name)
# Out:
# Malgun Gothic

# %%
# matplotlib의 rc(run command) 함수를 사용해서 font name(Malgun Gothic) 설정
matplotlib.rc('font', family = font_name)

# %% [markdown]
# ### Figure, Axes, Plot
# * Axes는 Plot이 실제 그려지는 공간
# * Figure는 Axes 보다 더 상위의 공간 : Figure을 여러개의 Axes로 분할해서 Plot를 그릴 수 있다
# * 비교) Axis는 X 축, Y축
# * seaborn의 barplot() 함수(막대그래프) 사용

# %%
seoul_df.reset_index(inplace= True)

# %%
seoul_df.head()
# Out:
#    index 행정구역     인구수    면적
# 0    124  강남구  526157  39.5
# 1    125  강동구  432028  24.6
# 2    126  강북구  310292  23.6
# 3    127  강서구  554709  41.4
# 4    128  관악구  484478  29.6

# %%
pop_order = seoul_df.sort_values('인구수', ascending=False)['행정구역']
pop_order
# Out:
# 17     송파구
# 3      강서구
# 8      노원구
# 0      강남구
# 4      관악구
# 21     은평구
# 18     양천구
# 16     성북구
# 1      강동구
# 14     서초구
# 6      구로구
# 24     중랑구
# 11     동작구
# 12     마포구
# 19    영등포구
# 5      광진구
# 10    동대문구
# 9      도봉구
# 2      강북구
# 13    서대문구
# 15     성동구
# 7      금천구
# 20     용산구
# 22     종로구
# 23      중구
# Name: 행정구역, dtype: str

# %%
area_order = seoul_df.sort_values('면적', ascending=False)['행정구역']
area_order
# Out:
# 14     서초구
# 3      강서구
# 0      강남구
# 8      노원구
# 17     송파구
# 21     은평구
# 4      관악구
# 1      강동구
# 16     성북구
# 19    영등포구
# 22     종로구
# 12     마포구
# 2      강북구
# 20     용산구
# 9      도봉구
# 6      구로구
# 24     중랑구
# 13    서대문구
# 18     양천구
# 5      광진구
# 15     성동구
# 11     동작구
# 10    동대문구
# 7      금천구
# 23      중구
# Name: 행정구역, dtype: str

# %%
# subplots() 함수를 사용하여 axes 객체를 생성하기
figure,(axes1,axes2) = plt.subplots(nrows=2,ncols=1)
figure.set_size_inches(18,12)
print(figure)
print(axes1)
print(axes2)

# seaborn의 barplot() 함수 호출하기 - 행정구역과 인구수
sns.barplot(data = seoul_df, x= "행정구역", y="인구수", ax = axes1, hue="행정구역", order=pop_order)
# seaborn의 barplot() 함수 호출하기 - 행정구역과 면적
sns.barplot(data = seoul_df, x= "행정구역", y="면적", ax = axes2, hue="행정구역", order=area_order)
plt.show()
# Out:
# Figure(1800x1200)
# Axes(0.125,0.53;0.775x0.35)
# Axes(0.125,0.11;0.775x0.35)

# %%
# 광역시도 이름을 인자로 받아서 인구수와 면적을 그려주는 함수
def show_pop_area(sido_name):
    # 입력받은 광역시도에 해당하는 DataFrame 객체생성
    sido_df = data.loc[data['광역시도'] == sido_name].copy()
    # Figure와 Axes 객체 생성
    figure, (axes1,axes2) = plt.subplots(nrows=2, ncols=1)
    # Figure size 확대
    figure.set_size_inches(18,12)
    
    pop_plot = sns.barplot(x='행정구역', y='인구수', data=sido_df.sort_values(by='인구수',ascending=False), ax=axes1,hue='행정구역')
    pop_plot.set_title(f'{sido_name} 행정구역별 인구수')
    
    area_plot = sns.barplot(x='행정구역', y='면적', data=sido_df.sort_values(by='면적',ascending=False), ax=axes2,hue='행정구역')
    area_plot.set_title(f'{sido_name} 행정구역별 면적')
    plt.show()

# %%
show_pop_area('부산광역시')

# %%
# 전국데이터의 광역시도의 인구수 
figure,axes1 = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(18,12)

sns.barplot(data=data, x='광역시도', y='인구수', ax=axes1, hue='광역시도')
plt.show()

# %%
print(type(seoul_df["인구수"].items()))
seoul_df["인구수"].items()
# Out:
# <class 'zip'>

# %%
for idx, value in enumerate(seoul_df["인구수"].items()):
    print(idx, value[1])
# Out:
# 0 526157
# 1 432028
# 2 310292
# 3 554709
# 4 484478
# 5 342909
# 6 401233
# 7 222566
# 8 547202
# 9 331682
# 10 342429
# 11 383917
# 12 364232
# 13 288543
# 14 407416
# 15 279939
# 16 434061
# 17 615487
# 18 453634
# 19 351837
# 20 208603
# 21 464236
# 22 140595
# 23 114967
# 24 391655

# %%
figure, ax1 = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(18,12)
sns.barplot(data=seoul_df, x="행정구역", y="인구수", ax=ax1,hue='행정구역')

#y축의 label값에 ,(콤마) 출력하기
ax1.get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))

#글자 90도 로테이션
for item in ax1.get_xticklabels(): 
    item.set_rotation(90)
for i, v in enumerate(seoul_df["인구수"].items()):
    ax1.text(i ,v[1], "{:,}".format(v[1]), color='m', va ='bottom', rotation=45)
#여백 없애줌
plt.tight_layout()

plt.show()
